# %%
import tensorflow as tf
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.layers import Dense, Embedding, Input, Add, Dot, Reshape, Flatten
from tensorflow.python.keras.optimizers import Adam
from tensorflow.python.keras.preprocessing.sequence import skipgrams
from tensorflow.python.keras.models import Model, load_model
import sklearn
import array
import pickle
import tarfile
from urllib.request import urlretrieve
import os
import sys
from os import listdir
import nltk
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import cosine_distances
from os.path import isfile, join
from scipy.sparse import csr_matrix, lil_matrix
import numpy as np
from scipy.sparse import save_npz, load_npz
from tensorflow.python.keras import backend as K
import random
import matplotlib.pyplot as plt
from tensorflow.python.keras.utils import plot_model
import pandas as pd
# %matplotlib inline

# %%
def getTextFromCooc(pathToFile):
    with open(pathToFile, 'r', encoding='utf8') as f:
        indexRow = 0
        headerText = []
        docs = []
        for row in f:
            if(indexRow == 0):
                for word in row.split(','):
                    headerText.append(word)
            else:
                indexNumber = 0
                isStringCreated = False
                for word2 in row.split(','):
                    if(indexNumber == 0):
                        pass
                    else:
                        if int(word2) == 1:
                            if(isStringCreated == False):
                                string = ''
                                isStringCreated = True
                            if(string == ""):
                                string = headerText[indexNumber-1]
                            else:
                                string = string +' '+headerText[indexNumber-1]
                    indexNumber += 1
                #string = string[2:]
                docs.append(string)
                docs = [s.replace("'", '"') for s in docs] # remove all the 8s 
            indexRow +=1
    with open('./docs/textTheGoodScents.txt','wb') as f:
        pickle.dump(docs, f)
    return [docs,headerText]

# %%
docs,headerText = getTextFromCooc('./Oniris/data.csv')
docs = [s.replace(" ", '') for s in docs]
docs = [s.replace('""', '" "') for s in docs]
headerText = headerText[1:]
print(len(headerText))
print(headerText)
# Out:
# 54
# ['"à noyaux"', '"agrumes"', '"alcool"', '"aldehyde"', '"amande amère"', '"amylique"', '"animal"', '"anise"', '"autre"', '"beurre"', '"boise"', '"caramel"', '"champignon"', '"chimique"', '"cuir"', '"doux"', '"empyreumatique"', '"epice"', '"fermentaire"', '"floral"', '"fruite"', '"fruits à pépins"', '"fruits cuits"', '"fruits exotiques"', '"fruits jaunes"', '"fruits noirs"', '"fruits rouges"', '"fruits secs"', '"fumé"', '"géranium"', '"inconnu"', '"lactique"', '"lactone"', '"légumes cuits"', '"levure"', '"malte"', '"menthe"', '"métallique"', '"mineral"', '"moisi-terreux"', '"noyau de cerise"', '"pharmaceutique"', '"pieds"', '"pomme de terre"', '"pyrazique"', '"rose"', '"soufre"', '"thiol vegetal"', '"vanille"', '"vegetal sec"', '"vegetal vert"', '"vinaigre"', '"violette"', '"vomi"\n']

# %%
v_size = len(headerText)
tokenizer = Tokenizer(num_words=v_size)
tokenizer.fit_on_texts(docs)

# %%
generate_cooc = False
def generate_cooc_matrix(text, tokenizer, window_size, n_vocab, use_weighting=True):
    sequences = tokenizer.texts_to_sequences(text)
    meanLen = 0
    meanNumber = 0
    for sequence in sequences:
        meanLen += len(sequence)
        meanNumber +=1
    meanLen = meanLen/meanNumber
    window_size = round(meanLen)
    cooc_mat = lil_matrix((n_vocab, n_vocab), dtype=np.float32)
    for sequence in sequences:
        window_size = int(len(sequence)/2)
        if(len(sequence) % 2 == 0):
            for i, wi in zip(np.arange(window_size, len(sequence)-window_size+1), sequence[window_size-1:-window_size]):
                context_window = sequence[i-window_size: i+window_size+1]
                distances = np.abs(np.arange(-(window_size-1), window_size+1))
                distances[window_size] = 1.0
                nom = np.ones(shape=(window_size*2,), dtype=np.float32)
                nom[window_size-1] = 0.0
                if use_weighting:
                    cooc_mat[wi, context_window] += nom/distances    # Update element
                else:
                    for y in range(0,len(sequence)-1):
                        nom = np.ones(shape=(window_size*2,), dtype=np.float32)
                        nom[y] = 0.0
                        cooc_mat[sequence[y], context_window] += nom
        else:
            for i, wi in zip(np.arange(window_size, len(sequence)-window_size), sequence[window_size:-window_size]):
                context_window = sequence[i-window_size: i+window_size+1]
                distances = np.abs(np.arange(-window_size, window_size+1))
                distances[window_size] = 1.0
                nom = np.ones(shape=(window_size*2 + 1,), dtype=np.float32)
                nom[window_size] = 0.0
                if use_weighting:
                    cooc_mat[wi, context_window] += nom/distances    # Update element
                else:
                    for y in range(0,len(sequence)-1):
                        nom = np.ones(shape=(window_size*2 + 1,), dtype=np.float32)
                        nom[y] = 0.0
                        cooc_mat[sequence[y], context_window] += nom
    return cooc_mat    

if not generate_cooc:
    cooc_mat = generate_cooc_matrix(docs, tokenizer, 4, v_size, False)
    print("Generated......")
    cooc_mat
    save_npz(os.path.join('datasets','cooc_mat.npz'), cooc_mat.tocsr())
else:
    cooc_mat = load_npz(os.path.join('datasets','cooc_mat.npz')).tolil()
    print('Cooc matrix of type {} was loaded from disk'.format(type(cooc_mat).__name__))
    
print(cooc_mat)
# Out:
# Generated......
#   (1, 2)	8.0
#   (1, 3)	8.0
#   (1, 4)	5.0
#   (1, 5)	5.0
#   (1, 6)	5.0
#   (1, 7)	6.0
#   (1, 8)	4.0
#   (1, 9)	2.0
#   (1, 10)	3.0
#   (1, 11)	4.0
#   (1, 12)	5.0
#   (1, 13)	6.0
#   (1, 14)	3.0
#   (1, 15)	2.0
#   (1, 16)	5.0
#   (1, 17)	4.0
#   (1, 18)	2.0
#   (1, 19)	2.0
#   (1, 20)	1.0
#   (1, 21)	2.0
#   (1, 22)	4.0
#   (1, 23)	4.0
#   (1, 24)	4.0
#   (1, 25)	2.0
#   (1, 26)	2.0
#   (1, 27)	3.0
#   (1, 28)	4.0
#   (1, 29)	4.0
#   (1, 30)	3.0
#   (1, 33)	1.0
#   (1, 34)	3.0
#   (1, 35)	4.0
#   (1, 36)	3.0
#   (1, 39)	2.0
#   (1, 40)	1.0
#   (1, 42)	1.0
#   (1, 43)	1.0
#   (1, 44)	1.0
#   (1, 45)	4.0
#   (1, 46)	3.0
#   (1, 47)	1.0
#   (1, 48)	1.0
#   (1, 49)	1.0
#   (1, 50)	1.0
#   (1, 51)	2.0
#   (1, 53)	1.0
#   (2, 1)	8.0
#   (2, 3)	21.0
#   (2, 4)	6.0
#   (2, 5)	3.0
#   (2, 6)	5.0
#   (2, 7)	3.0
#   (2, 8)	6.0
#   (2, 9)	8.0
#   (2, 10)	7.0
#   (2, 11)	3.0
#   (2, 12)	5.0
#   (2, 13)	2.0
#   (2, 14)	4.0
#   (2, 15)	3.0
#   (2, 16)	3.0
#   (2, 17)	4.0
#   (2, 18)	4.0
#   (2, 19)	3.0
#   (2, 20)	3.0
#   (2, 21)	3.0
#   (2, 22)	3.0
#   (2, 23)	1.0
#   (2, 24)	5.0
#   (2, 25)	2.0
#   (2, 26)	5.0
#   (2, 27)	3.0
#   (2, 28)	4.0
#   (2, 29)	4.0
#   (2, 30)	2.0
#   (2, 32)	3.0
#   (2, 33)	2.0
#   (2, 34)	3.0
#   (2, 35)	3.0
#   (2, 36)	2.0
#   (2, 37)	1.0
#   (2, 38)	2.0
#   (2, 40)	2.0
#   (2, 41)	2.0
#   (2, 42)	2.0
#   (2, 43)	2.0
#   (2, 44)	2.0
#   (2, 45)	3.0
#   (2, 46)	2.0
#   (2, 47)	1.0
#   (2, 48)	1.0
#   (2, 49)	3.0
#   (2, 50)	3.0
#   (2, 52)	1.0
#   (3, 1)	4.0
#   (3, 2)	9.0
#   (3, 4)	2.0
#   (3, 5)	3.0
#   (3, 6)	3.0
#   (3, 7)	3.0
#   (3, 8)	2.0
#   (3, 9)	3.0
#   (3, 10)	3.0
#   (3, 12)	4.0
#   (3, 14)	4.0
#   (3, 15)	1.0
#   (3, 16)	1.0
#   (3, 17)	1.0
#   (3, 18)	3.0
#   (3, 19)	2.0
#   (3, 20)	2.0
#   (3, 21)	1.0
#   (3, 22)	2.0
#   (3, 23)	1.0
#   (3, 24)	1.0
#   (3, 26)	1.0
#   (3, 27)	1.0
#   (3, 28)	3.0
#   (3, 29)	3.0
#   (3, 30)	1.0
#   (3, 32)	2.0
#   (3, 33)	1.0
#   (3, 34)	2.0
#   (3, 35)	1.0
#   (3, 36)	1.0
#   (3, 37)	1.0
#   (3, 38)	1.0
#   (3, 40)	2.0
#   (3, 41)	1.0
#   (3, 42)	1.0
#   (3, 43)	1.0
#   (3, 44)	1.0
#   (3, 45)	3.0
#   (3, 46)	1.0
#   (3, 47)	1.0
#   (3, 48)	1.0
#   (3, 49)	2.0
#   (3, 50)	2.0
#   (4, 1)	5.0
#   (4, 2)	6.0
#   (4, 3)	6.0
#   (4, 5)	5.0
#   (4, 6)	4.0
#   (4, 7)	5.0
#   (4, 8)	1.0
#   (4, 9)	5.0
#   (4, 10)	8.0
#   (4, 11)	4.0
#   (4, 12)	3.0
#   (4, 13)	5.0
#   (4, 14)	7.0
#   (4, 15)	6.0
#   (4, 16)	3.0
#   (4, 17)	2.0
#   (4, 18)	2.0
#   (4, 19)	2.0
#   (4, 20)	5.0
#   (4, 21)	2.0
#   (4, 22)	1.0
#   (4, 23)	2.0
#   (4, 24)	2.0
#   (4, 26)	1.0
#   (4, 27)	4.0
#   (4, 28)	1.0
#   (4, 29)	1.0
#   (4, 30)	4.0
#   (4, 31)	2.0
#   (4, 32)	1.0
#   (4, 33)	3.0
#   (4, 34)	4.0
#   (4, 35)	1.0
#   (4, 36)	2.0
#   (4, 37)	3.0
#   (4, 38)	2.0
#   (4, 39)	3.0
#   (4, 40)	3.0
#   (4, 41)	1.0
#   (4, 42)	4.0
#   (4, 43)	4.0
#   (4, 44)	4.0
#   (4, 45)	2.0
#   (4, 47)	2.0
#   (4, 48)	2.0
#   (4, 49)	1.0
#   (4, 50)	1.0
#   (4, 51)	1.0
#   (4, 52)	1.0
#   (5, 1)	1.0
#   (5, 2)	1.0
#   (5, 3)	1.0
#   (5, 4)	5.0
#   (5, 6)	2.0
#   (5, 8)	1.0
#   (5, 9)	2.0
#   (5, 10)	2.0
#   (5, 11)	1.0
#   (5, 12)	1.0
#   (5, 13)	3.0
#   (5, 14)	3.0
#   (5, 15)	1.0
#   (5, 16)	2.0
#   (5, 23)	1.0
#   (5, 24)	2.0
#   (5, 27)	1.0
#   (5, 28)	1.0
#   (5, 29)	1.0
#   (5, 30)	2.0
#   (5, 31)	1.0
#   (5, 34)	1.0
#   (5, 35)	1.0
#   (5, 37)	4.0
#   (5, 39)	1.0
#   (5, 40)	1.0
#   (5, 42)	2.0
#   (5, 43)	2.0
#   (5, 44)	2.0
#   (5, 45)	1.0
#   (5, 47)	2.0
#   (5, 48)	1.0
#   (6, 1)	5.0
#   (6, 2)	5.0
#   (6, 3)	5.0
#   (6, 4)	4.0
#   (6, 5)	4.0
#   (6, 7)	4.0
#   (6, 8)	1.0
#   (6, 9)	4.0
#   (6, 10)	3.0
#   (6, 11)	2.0
#   (6, 12)	5.0
#   (6, 13)	3.0
#   (6, 14)	4.0
#   (6, 15)	3.0
#   (6, 16)	2.0
#   (6, 17)	2.0
#   (6, 18)	2.0
#   (6, 19)	5.0
#   (6, 20)	3.0
#   (6, 21)	2.0
#   (6, 22)	1.0
#   (6, 23)	1.0
#   (6, 24)	3.0
#   (6, 25)	2.0
#   (6, 27)	1.0
#   (6, 28)	3.0
#   (6, 29)	3.0
#   (6, 30)	1.0
#   (6, 31)	3.0
#   (6, 32)	3.0
#   (6, 33)	1.0
#   (6, 35)	3.0
#   (6, 37)	2.0
#   (6, 38)	1.0
#   (6, 39)	2.0
#   (6, 40)	1.0
#   (6, 41)	2.0
#   (6, 42)	1.0
#   (6, 43)	1.0
#   (6, 44)	1.0
#   (6, 45)	1.0
#   (6, 46)	1.0
#   (6, 47)	2.0
#   (6, 49)	1.0
#   (6, 50)	1.0
#   (6, 52)	2.0
#   (6, 53)	1.0
#   (7, 1)	5.0
#   (7, 2)	3.0
#   (7, 3)	3.0
#   (7, 4)	4.0
#   (7, 5)	2.0
#   (7, 6)	3.0
#   (7, 8)	1.0
#   (7, 9)	2.0
#   (7, 10)	2.0
#   (7, 11)	2.0
#   (7, 12)	4.0
#   (7, 13)	2.0
#   (7, 14)	1.0
#   (7, 15)	3.0
#   (7, 16)	2.0
#   (7, 17)	1.0
#   (7, 18)	4.0
#   (7, 19)	1.0
#   (7, 20)	2.0
#   (7, 21)	1.0
#   (7, 23)	1.0
#   (7, 25)	1.0
#   (7, 26)	1.0
#   (7, 30)	1.0
#   (7, 31)	2.0
#   (7, 32)	1.0
#   (7, 34)	1.0
#   (7, 35)	1.0
#   (7, 36)	2.0
#   (7, 37)	2.0
#   (7, 38)	2.0
#   (7, 39)	2.0
#   (7, 40)	2.0
#   (7, 42)	1.0
#   (7, 43)	1.0
#   (7, 44)	1.0
#   (7, 45)	2.0
#   (7, 46)	1.0
#   (7, 47)	1.0
#   (7, 48)	1.0
#   (7, 50)	2.0
#   (7, 51)	1.0
#   (7, 52)	1.0
#   (8, 1)	4.0
#   (8, 2)	6.0
#   (8, 3)	6.0
#   (8, 4)	1.0
#   (8, 5)	2.0
#   (8, 6)	1.0
#   (8, 7)	2.0
#   (8, 9)	4.0
#   (8, 10)	1.0
#   (8, 11)	5.0
#   (8, 12)	3.0
#   (8, 13)	2.0
#   (8, 14)	3.0
#   (8, 15)	3.0
#   (8, 16)	3.0
#   (8, 17)	1.0
#   (8, 18)	4.0
#   (8, 19)	2.0
#   (8, 20)	3.0
#   (8, 21)	4.0
#   (8, 22)	5.0
#   (8, 23)	3.0
#   (8, 24)	4.0
#   (8, 25)	4.0
#   (8, 26)	4.0
#   (8, 27)	2.0
#   (8, 28)	3.0
#   (8, 29)	3.0
#   (8, 30)	1.0
#   (8, 32)	2.0
#   (8, 33)	1.0
#   (8, 34)	2.0
#   (8, 36)	1.0
#   (8, 37)	1.0
#   (8, 39)	1.0
#   (8, 40)	1.0
#   (8, 41)	2.0
#   (8, 42)	2.0
#   (8, 43)	2.0
#   (8, 44)	2.0
#   (8, 46)	1.0
#   (8, 47)	1.0
#   (8, 48)	2.0
#   (8, 49)	3.0
#   (8, 50)	3.0
#   (8, 51)	1.0
#   (8, 52)	1.0
#   (8, 53)	1.0
#   (9, 1)	2.0
#   (9, 2)	8.0
#   (9, 3)	8.0
#   (9, 4)	5.0
#   (9, 5)	3.0
#   (9, 6)	4.0
#   (9, 7)	2.0
#   (9, 8)	4.0
#   (9, 10)	5.0
#   (9, 11)	3.0
#   (9, 12)	3.0
#   (9, 13)	2.0
#   (9, 14)	3.0
#   (9, 15)	4.0
#   (9, 16)	2.0
#   (9, 17)	1.0
#   (9, 18)	4.0
#   (9, 19)	2.0
#   (9, 20)	4.0
#   (9, 21)	2.0
#   (9, 22)	1.0
#   (9, 23)	1.0
#   (9, 24)	2.0
#   (9, 25)	4.0
#   (9, 26)	3.0
#   (9, 27)	1.0
#   (9, 28)	3.0
#   (9, 29)	3.0
#   (9, 31)	1.0
#   (9, 32)	2.0
#   (9, 33)	2.0
#   (9, 34)	3.0
#   (9, 35)	2.0
#   (9, 36)	1.0
#   (9, 38)	1.0
#   (9, 39)	1.0
#   (9, 40)	3.0
#   (9, 41)	3.0
#   (9, 42)	2.0
#   (9, 43)	2.0
#   (9, 44)	2.0
#   (9, 45)	2.0
#   (9, 46)	1.0
#   (9, 47)	1.0
#   (9, 48)	2.0
#   (9, 49)	2.0
#   (9, 50)	2.0
#   (9, 52)	1.0
#   (9, 53)	1.0
#   (10, 1)	3.0
#   (10, 2)	7.0
#   (10, 3)	7.0
#   (10, 4)	8.0
#   (10, 5)	2.0
#   (10, 6)	3.0
#   (10, 7)	4.0
#   (10, 8)	1.0
#   (10, 9)	5.0
#   (10, 11)	2.0
#   (10, 12)	1.0
#   (10, 13)	3.0
#   (10, 14)	2.0
#   (10, 15)	4.0
#   (10, 17)	3.0
#   (10, 18)	4.0
#   (10, 19)	3.0
#   (10, 20)	2.0
#   (10, 21)	3.0
#   (10, 22)	1.0
#   (10, 23)	1.0
#   (10, 24)	1.0
#   (10, 26)	3.0
#   (10, 27)	3.0
#   (10, 28)	3.0
#   (10, 29)	3.0
#   (10, 30)	2.0
#   (10, 31)	3.0
#   (10, 32)	3.0
#   (10, 33)	1.0
#   (10, 34)	1.0
#   (10, 35)	1.0
#   (10, 37)	1.0
#   (10, 39)	2.0
#   (10, 40)	2.0
#   (10, 41)	2.0
#   (10, 42)	2.0
#   (10, 43)	2.0
#   (10, 44)	2.0
#   (10, 45)	1.0
#   (10, 46)	1.0
#   (10, 47)	1.0
#   (10, 48)	2.0
#   (10, 49)	1.0
#   (11, 1)	4.0
#   (11, 2)	3.0
#   (11, 3)	3.0
#   (11, 4)	4.0
#   (11, 5)	1.0
#   (11, 6)	2.0
#   (11, 7)	3.0
#   (11, 8)	5.0
#   (11, 9)	3.0
#   (11, 10)	2.0
#   (11, 12)	5.0
#   (11, 13)	2.0
#   (11, 14)	3.0
#   (11, 15)	4.0
#   (11, 16)	1.0
#   (11, 17)	1.0
#   (11, 18)	1.0
#   (11, 19)	1.0
#   (11, 20)	4.0
#   (11, 21)	2.0
#   (11, 22)	1.0
#   (11, 23)	3.0
#   (11, 24)	2.0
#   (11, 25)	3.0
#   (11, 26)	3.0
#   (11, 27)	1.0
#   (11, 30)	1.0
#   (11, 31)	1.0
#   (11, 32)	1.0
#   (11, 33)	2.0
#   (11, 34)	1.0
#   (11, 35)	2.0
#   (11, 36)	4.0
#   (11, 37)	1.0
#   (11, 38)	2.0
#   (11, 39)	2.0
#   (11, 40)	2.0
#   (11, 45)	1.0
#   (11, 51)	3.0
#   (11, 52)	1.0
#   (11, 53)	1.0
#   (12, 1)	5.0
#   (12, 2)	5.0
#   (12, 3)	5.0
#   (12, 4)	3.0
#   (12, 5)	4.0
#   (12, 6)	5.0
#   (12, 7)	4.0
#   (12, 8)	3.0
#   (12, 9)	3.0
#   (12, 10)	1.0
#   (12, 11)	5.0
#   (12, 14)	3.0
#   (12, 15)	3.0
#   (12, 16)	1.0
#   (12, 19)	1.0
#   (12, 20)	4.0
#   (12, 21)	2.0
#   (12, 22)	2.0
#   (12, 23)	3.0
#   (12, 25)	2.0
#   (12, 26)	3.0
#   (12, 28)	2.0
#   (12, 29)	2.0
#   (12, 31)	1.0
#   (12, 32)	3.0
#   (12, 33)	3.0
#   (12, 34)	2.0
#   (12, 35)	2.0
#   (12, 36)	2.0
#   (12, 37)	1.0
#   (12, 38)	3.0
#   (12, 39)	1.0
#   (12, 40)	1.0
#   (12, 45)	2.0
#   (12, 47)	1.0
#   (12, 50)	1.0
#   (12, 51)	1.0
#   (12, 52)	3.0
#   (12, 53)	3.0
#   (13, 1)	6.0
#   (13, 2)	2.0
#   (13, 3)	2.0
#   (13, 4)	5.0
#   (13, 5)	5.0
#   (13, 6)	3.0
#   (13, 7)	2.0
#   (13, 8)	2.0
#   (13, 9)	2.0
#   (13, 10)	3.0
#   (13, 11)	2.0
#   (13, 14)	3.0
#   (13, 15)	2.0
#   (13, 16)	4.0
#   (13, 17)	2.0
#   (13, 18)	2.0
#   (13, 19)	3.0
#   (13, 20)	1.0
#   (13, 21)	2.0
#   (13, 22)	1.0
#   (13, 23)	1.0
#   (13, 24)	2.0
#   (13, 27)	4.0
#   (13, 28)	1.0
#   (13, 29)	1.0
#   (13, 30)	3.0
#   (13, 31)	1.0
#   (13, 34)	1.0
#   (13, 35)	1.0
#   (13, 37)	1.0
#   (13, 39)	2.0
#   (13, 41)	1.0
#   (13, 42)	3.0
#   (13, 43)	3.0
#   (13, 44)	3.0
#   (13, 45)	1.0
#   (13, 46)	2.0
#   (13, 47)	1.0
#   (13, 48)	2.0
#   (14, 1)	1.0
#   (14, 2)	2.0
#   (14, 3)	2.0
#   (14, 4)	2.0
#   (14, 5)	1.0
#   (14, 6)	2.0
#   (14, 8)	1.0
#   (14, 10)	1.0
#   (14, 13)	1.0
#   (14, 16)	1.0
#   (14, 17)	2.0
#   (14, 18)	1.0
#   (14, 19)	1.0
#   (14, 21)	2.0
#   (14, 22)	1.0
#   (14, 23)	2.0
#   (14, 24)	2.0
#   (14, 27)	1.0
#   (14, 28)	1.0
#   (14, 29)	1.0
#   (14, 30)	1.0
#   (14, 31)	1.0
#   (14, 37)	2.0
#   (14, 39)	1.0
#   (14, 41)	1.0
#   (14, 45)	1.0
#   (14, 48)	1.0
#   (14, 49)	1.0
#   (14, 50)	1.0
#   (15, 1)	2.0
#   (15, 2)	3.0
#   (15, 3)	3.0
#   (15, 4)	6.0
#   (15, 5)	2.0
#   (15, 6)	3.0
#   (15, 7)	4.0
#   (15, 8)	3.0
#   (15, 9)	4.0
#   (15, 10)	4.0
#   (15, 11)	4.0
#   (15, 12)	3.0
#   (15, 13)	2.0
#   (15, 14)	4.0
#   (15, 18)	1.0
#   (15, 19)	2.0
#   (15, 20)	3.0
#   (15, 21)	1.0
#   (15, 22)	1.0
#   (15, 23)	2.0
#   (15, 24)	2.0
#   (15, 25)	1.0
#   (15, 26)	1.0
#   (15, 28)	1.0
#   (15, 29)	1.0
#   (15, 30)	3.0
#   (15, 31)	2.0
#   (15, 32)	1.0
#   (15, 33)	2.0
#   (15, 34)	1.0
#   (15, 35)	2.0
#   (15, 36)	2.0
#   (15, 37)	1.0
#   (15, 38)	2.0
#   (15, 39)	2.0
#   (15, 40)	2.0
#   (15, 42)	2.0
#   (15, 43)	2.0
#   (15, 44)	2.0
#   (15, 46)	1.0
#   (15, 48)	1.0
#   (15, 51)	1.0
#   (15, 52)	1.0
#   (15, 53)	1.0
#   (16, 1)	5.0
#   (16, 2)	3.0
#   (16, 3)	3.0
#   (16, 4)	3.0
#   (16, 5)	4.0
#   (16, 6)	2.0
#   (16, 7)	2.0
#   (16, 8)	3.0
#   (16, 9)	1.0
#   (16, 11)	1.0
#   (16, 12)	1.0
#   (16, 13)	3.0
#   (16, 14)	2.0
#   (16, 17)	2.0
#   (16, 18)	3.0
#   (16, 19)	1.0
#   (16, 20)	1.0
#   (16, 24)	2.0
#   (16, 25)	1.0
#   (16, 27)	1.0
#   (16, 30)	2.0
#   (16, 31)	2.0
#   (16, 32)	1.0
#   (16, 33)	1.0
#   (16, 34)	1.0
#   (16, 35)	2.0
#   (16, 36)	1.0
#   (16, 37)	2.0
#   (16, 39)	1.0
#   (16, 45)	2.0
#   (16, 47)	2.0
#   (16, 50)	1.0
#   (17, 1)	4.0
#   (17, 2)	4.0
#   (17, 3)	4.0
#   (17, 4)	2.0
#   (17, 6)	2.0
#   (17, 7)	2.0
#   (17, 8)	1.0
#   (17, 9)	1.0
#   (17, 10)	3.0
#   (17, 11)	1.0
#   (17, 13)	2.0
#   (17, 14)	2.0
#   (17, 16)	2.0
#   (17, 18)	2.0
#   (17, 19)	1.0
#   (17, 21)	2.0
#   (17, 22)	2.0
#   (17, 23)	2.0
#   (17, 24)	1.0
#   (17, 26)	1.0
#   (17, 27)	1.0
#   (17, 28)	1.0
#   (17, 29)	1.0
#   (17, 30)	1.0
#   (17, 31)	2.0
#   (17, 32)	1.0
#   (17, 33)	2.0
#   (17, 34)	1.0
#   (17, 35)	1.0
#   (17, 36)	3.0
#   (17, 38)	1.0
#   (17, 39)	3.0
#   (17, 40)	1.0
#   (17, 45)	1.0
#   (17, 46)	3.0
#   (17, 47)	1.0
#   (17, 48)	1.0
#   (17, 50)	1.0
#   (17, 51)	1.0
#   (18, 1)	2.0
#   (18, 2)	4.0
#   (18, 3)	4.0
#   (18, 4)	2.0
#   (18, 5)	2.0
#   (18, 6)	2.0
#   (18, 7)	5.0
#   (18, 8)	4.0
#   (18, 9)	4.0
#   (18, 10)	4.0
#   (18, 11)	1.0
#   (18, 13)	2.0
#   (18, 14)	2.0
#   (18, 15)	1.0
#   (18, 16)	3.0
#   (18, 17)	2.0
#   (18, 19)	3.0
#   (18, 20)	3.0
#   (18, 21)	2.0
#   (18, 22)	3.0
#   (18, 23)	1.0
#   (18, 25)	2.0
#   (18, 26)	3.0
#   (18, 28)	1.0
#   (18, 29)	1.0
#   (18, 31)	1.0
#   (18, 32)	1.0
#   (18, 34)	1.0
#   (18, 37)	1.0
#   (18, 40)	2.0
#   (18, 41)	2.0
#   (18, 42)	1.0
#   (18, 43)	1.0
#   (18, 44)	1.0
#   (18, 45)	1.0
#   (18, 46)	1.0
#   (18, 47)	2.0
#   (18, 48)	2.0
#   (18, 49)	2.0
#   (18, 50)	2.0
#   (18, 51)	1.0
#   (19, 1)	2.0
#   (19, 2)	3.0
#   (19, 3)	3.0
#   (19, 4)	2.0
#   (19, 5)	1.0
#   (19, 6)	5.0
#   (19, 7)	2.0
#   (19, 8)	2.0
#   (19, 9)	2.0
#   (19, 10)	3.0
#   (19, 11)	1.0
#   (19, 12)	1.0
#   (19, 13)	3.0
#   (19, 14)	3.0
#   (19, 15)	2.0
#   (19, 16)	2.0
#   (19, 17)	1.0
#   (19, 18)	3.0
#   (19, 20)	1.0
#   (19, 21)	2.0
#   (19, 22)	2.0
#   (19, 24)	1.0
#   (19, 25)	1.0
#   (19, 27)	1.0
#   (19, 28)	2.0
#   (19, 29)	2.0
#   (19, 31)	3.0
#   (19, 32)	2.0
#   (19, 33)	1.0
#   (19, 34)	1.0
#   (19, 35)	1.0
#   (19, 36)	2.0
#   (19, 37)	1.0
#   (19, 40)	1.0
#   (19, 41)	3.0
#   (19, 45)	1.0
#   (19, 46)	1.0
#   (19, 47)	1.0
#   (19, 49)	1.0
#   (19, 50)	2.0
#   (19, 51)	1.0
#   (20, 2)	3.0
#   (20, 3)	3.0
#   (20, 4)	3.0
#   (20, 7)	1.0
#   (20, 8)	2.0
#   (20, 9)	4.0
#   (20, 10)	2.0
#   (20, 11)	3.0
#   (20, 12)	2.0
#   (20, 14)	3.0
#   (20, 15)	3.0
#   (20, 18)	2.0
#   (20, 19)	1.0
#   (20, 21)	1.0
#   (20, 23)	1.0
#   (20, 24)	1.0
#   (20, 25)	2.0
#   (20, 26)	2.0
#   (20, 32)	2.0
#   (20, 33)	3.0
#   (20, 34)	1.0
#   (20, 36)	1.0
#   (20, 38)	1.0
#   (20, 39)	1.0
#   (20, 40)	1.0
#   (20, 42)	1.0
#   (20, 43)	1.0
#   (20, 44)	1.0
#   (20, 46)	1.0
#   (20, 48)	1.0
#   (20, 51)	1.0
#   (20, 53)	1.0
#   (21, 1)	2.0
#   (21, 2)	3.0
#   (21, 3)	3.0
#   (21, 4)	2.0
#   (21, 6)	1.0
#   (21, 7)	1.0
#   (21, 8)	3.0
#   (21, 9)	2.0
#   (21, 10)	2.0
#   (21, 11)	2.0
#   (21, 12)	1.0
#   (21, 13)	2.0
#   (21, 14)	2.0
#   (21, 17)	2.0
#   (21, 18)	2.0
#   (21, 19)	1.0
#   (21, 20)	1.0
#   (21, 22)	2.0
#   (21, 23)	2.0
#   (21, 25)	3.0
#   (21, 27)	2.0
#   (21, 28)	2.0
#   (21, 29)	2.0
#   (21, 32)	1.0
#   (21, 33)	1.0
#   (21, 34)	2.0
#   (21, 37)	2.0
#   (21, 39)	2.0
#   (21, 40)	1.0
#   (21, 41)	2.0
#   (21, 46)	1.0
#   (21, 47)	1.0
#   (21, 48)	2.0
#   (21, 49)	2.0
#   (21, 50)	1.0
#   (21, 53)	1.0
#   (22, 1)	4.0
#   (22, 2)	3.0
#   (22, 3)	3.0
#   (22, 4)	1.0
#   (22, 5)	2.0
#   (22, 6)	1.0
#   (22, 8)	5.0
#   (22, 9)	1.0
#   (22, 10)	1.0
#   (22, 11)	1.0
#   (22, 12)	2.0
#   (22, 13)	1.0
#   (22, 14)	3.0
#   (22, 15)	1.0
#   (22, 17)	2.0
#   (22, 18)	3.0
#   (22, 19)	2.0
#   (22, 21)	2.0
#   (22, 23)	2.0
#   (22, 25)	1.0
#   (22, 26)	3.0
#   (22, 27)	1.0
#   (22, 28)	2.0
#   (22, 29)	2.0
#   (22, 33)	1.0
#   (22, 34)	3.0
#   (22, 35)	1.0
#   (22, 36)	1.0
#   (22, 37)	1.0
#   (22, 40)	1.0
#   (22, 41)	3.0
#   (22, 46)	2.0
#   (22, 47)	1.0
#   (22, 48)	1.0
#   (22, 49)	3.0
#   (22, 50)	1.0
#   (22, 51)	1.0
#   (22, 53)	1.0
#   (23, 1)	4.0
#   (23, 2)	1.0
#   (23, 3)	1.0
#   (23, 4)	2.0
#   (23, 5)	3.0
#   (23, 6)	1.0
#   (23, 7)	2.0
#   (23, 8)	3.0
#   (23, 9)	1.0
#   (23, 10)	1.0
#   (23, 11)	3.0
#   (23, 12)	3.0
#   (23, 13)	1.0
#   (23, 14)	4.0
#   (23, 15)	2.0
#   (23, 17)	2.0
#   (23, 18)	1.0
#   (23, 20)	1.0
#   (23, 21)	3.0
#   (23, 22)	2.0
#   (23, 24)	1.0
#   (23, 25)	1.0
#   (23, 26)	2.0
#   (23, 27)	1.0
#   (23, 28)	2.0
#   (23, 29)	2.0
#   (23, 30)	1.0
#   (23, 32)	1.0
#   (23, 33)	1.0
#   (23, 35)	2.0
#   (23, 39)	3.0
#   (23, 40)	1.0
#   (23, 42)	1.0
#   (23, 43)	1.0
#   (23, 44)	1.0
#   (23, 45)	1.0
#   (23, 48)	1.0
#   (23, 51)	2.0
#   (23, 53)	2.0
#   (24, 1)	4.0
#   (24, 2)	5.0
#   (24, 3)	5.0
#   (24, 4)	2.0
#   (24, 5)	2.0
#   (24, 6)	3.0
#   (24, 7)	1.0
#   (24, 8)	4.0
#   (24, 9)	2.0
#   (24, 10)	1.0
#   (24, 11)	2.0
#   (24, 13)	2.0
#   (24, 14)	2.0
#   (24, 15)	2.0
#   (24, 16)	2.0
#   (24, 17)	1.0
#   (24, 19)	1.0
#   (24, 20)	1.0
#   (24, 23)	1.0
#   (24, 25)	2.0
#   (24, 26)	1.0
#   (24, 27)	1.0
#   (24, 28)	1.0
#   (24, 29)	1.0
#   (24, 30)	3.0
#   (24, 31)	1.0
#   (24, 35)	1.0
#   (24, 37)	1.0
#   (24, 42)	1.0
#   (24, 43)	1.0
#   (24, 44)	1.0
#   (24, 45)	1.0
#   (24, 48)	1.0
#   (25, 1)	1.0
#   (25, 2)	2.0
#   (25, 3)	2.0
#   (25, 5)	1.0
#   (25, 6)	2.0
#   (25, 7)	1.0
#   (25, 8)	4.0
#   (25, 9)	4.0
#   (25, 11)	2.0
#   (25, 12)	2.0
#   (25, 15)	1.0
#   (25, 16)	1.0
#   (25, 18)	2.0
#   (25, 19)	1.0
#   (25, 20)	3.0
#   (25, 21)	3.0
#   (25, 22)	1.0
#   (25, 23)	1.0
#   (25, 24)	2.0
#   (25, 26)	1.0
#   (25, 28)	2.0
#   (25, 29)	2.0
#   (25, 32)	1.0
#   (25, 33)	1.0
#   (25, 34)	1.0
#   (25, 35)	1.0
#   (25, 37)	1.0
#   (25, 39)	1.0
#   (25, 40)	1.0
#   (25, 41)	1.0
#   (25, 47)	1.0
#   (25, 48)	1.0
#   (25, 49)	1.0
#   (25, 52)	1.0
#   (25, 53)	2.0
#   (26, 1)	2.0
#   (26, 2)	5.0
#   (26, 3)	5.0
#   (26, 4)	1.0
#   (26, 5)	1.0
#   (26, 7)	1.0
#   (26, 8)	4.0
#   (26, 9)	3.0
#   (26, 10)	3.0
#   (26, 11)	3.0
#   (26, 12)	3.0
#   (26, 14)	2.0
#   (26, 15)	1.0
#   (26, 17)	1.0
#   (26, 18)	3.0
#   (26, 20)	2.0
#   (26, 22)	3.0
#   (26, 23)	2.0
#   (26, 24)	1.0
#   (26, 25)	1.0
#   (26, 35)	2.0
#   (26, 40)	1.0
#   (26, 46)	1.0
#   (26, 50)	1.0
#   (26, 51)	1.0
#   (26, 52)	1.0
#   (26, 53)	1.0
#   (27, 1)	3.0
#   (27, 2)	3.0
#   (27, 3)	3.0
#   (27, 4)	4.0
#   (27, 5)	3.0
#   (27, 6)	1.0
#   (27, 8)	2.0
#   (27, 9)	1.0
#   (27, 10)	3.0
#   (27, 11)	1.0
#   (27, 13)	4.0
#   (27, 14)	2.0
#   (27, 16)	1.0
#   (27, 17)	1.0
#   (27, 19)	1.0
#   (27, 21)	3.0
#   (27, 22)	1.0
#   (27, 23)	1.0
#   (27, 24)	1.0
#   (27, 28)	3.0
#   (27, 29)	3.0
#   (27, 30)	1.0
#   (27, 32)	1.0
#   (27, 34)	2.0
#   (27, 35)	1.0
#   (27, 38)	1.0
#   (27, 39)	1.0
#   (27, 42)	1.0
#   (27, 43)	1.0
#   (27, 44)	1.0
#   (27, 48)	2.0
#   (27, 49)	1.0
#   (28, 1)	4.0
#   (28, 2)	4.0
#   (28, 3)	4.0
#   (28, 4)	1.0
#   (28, 5)	3.0
#   (28, 6)	3.0
#   (28, 8)	3.0
#   (28, 9)	3.0
#   (28, 10)	3.0
#   (28, 12)	2.0
#   (28, 13)	1.0
#   (28, 14)	1.0
#   (28, 15)	1.0
#   (28, 17)	1.0
#   (28, 18)	1.0
#   (28, 19)	2.0
#   (28, 21)	4.0
#   (28, 22)	2.0
#   (28, 23)	2.0
#   (28, 24)	1.0
#   (28, 25)	2.0
#   (28, 27)	3.0
#   (28, 29)	8.0
#   (28, 32)	2.0
#   (28, 33)	1.0
#   (28, 34)	2.0
#   (28, 35)	1.0
#   (28, 38)	1.0
#   (28, 39)	1.0
#   (28, 40)	1.0
#   (28, 41)	1.0
#   (28, 42)	1.0
#   (28, 43)	1.0
#   (28, 44)	1.0
#   (28, 45)	1.0
#   (28, 47)	1.0
#   (28, 48)	2.0
#   (28, 49)	2.0
#   (29, 1)	4.0
#   (29, 2)	4.0
#   (29, 3)	4.0
#   (29, 4)	1.0
#   (29, 5)	3.0
#   (29, 6)	3.0
#   (29, 8)	3.0
#   (29, 9)	3.0
#   (29, 10)	3.0
#   (29, 12)	2.0
#   (29, 13)	1.0
#   (29, 14)	1.0
#   (29, 15)	1.0
#   (29, 17)	1.0
#   (29, 18)	1.0
#   (29, 19)	2.0
#   (29, 21)	4.0
#   (29, 22)	2.0
#   (29, 23)	2.0
#   (29, 24)	1.0
#   (29, 25)	2.0
#   (29, 27)	3.0
#   (29, 28)	8.0
#   (29, 32)	2.0
#   (29, 33)	1.0
#   (29, 34)	2.0
#   (29, 35)	1.0
#   (29, 38)	1.0
#   (29, 39)	1.0
#   (29, 40)	1.0
#   (29, 41)	1.0
#   (29, 42)	1.0
#   (29, 43)	1.0
#   (29, 44)	1.0
#   (29, 45)	1.0
#   (29, 47)	1.0
#   (29, 48)	2.0
#   (29, 49)	2.0
#   (30, 1)	3.0
#   (30, 2)	2.0
#   (30, 3)	2.0
#   (30, 4)	4.0
#   (30, 5)	3.0
#   (30, 6)	1.0
#   (30, 7)	2.0
#   (30, 8)	1.0
#   (30, 10)	2.0
#   (30, 11)	1.0
#   (30, 13)	3.0
#   (30, 14)	2.0
#   (30, 15)	3.0
#   (30, 16)	2.0
#   (30, 17)	1.0
#   (30, 23)	1.0
#   (30, 24)	3.0
#   (30, 27)	1.0
#   (30, 31)	1.0
#   (30, 34)	1.0
#   (30, 35)	1.0
#   (30, 37)	1.0
#   (30, 39)	1.0
#   (30, 40)	1.0
#   (30, 42)	1.0
#   (30, 43)	1.0
#   (30, 44)	1.0
#   (30, 45)	1.0
#   (30, 47)	2.0
#   (31, 4)	2.0
#   (31, 5)	1.0
#   (31, 6)	2.0
#   (31, 7)	3.0
#   (31, 9)	1.0
#   (31, 10)	2.0
#   (31, 11)	1.0
#   (31, 12)	1.0
#   (31, 13)	1.0
#   (31, 14)	1.0
#   (31, 15)	2.0
#   (31, 16)	3.0
#   (31, 17)	2.0
#   (31, 18)	1.0
#   (31, 19)	2.0
#   (31, 24)	1.0
#   (31, 30)	1.0
#   (31, 33)	1.0
#   (31, 36)	1.0
#   (31, 37)	2.0
#   (31, 38)	1.0
#   (31, 39)	2.0
#   (31, 40)	1.0
#   (31, 41)	1.0
#   (31, 47)	1.0
#   (32, 2)	3.0
#   (32, 3)	3.0
#   (32, 4)	1.0
#   (32, 5)	1.0
#   (32, 6)	3.0
#   (32, 7)	1.0
#   (32, 8)	2.0
#   (32, 9)	2.0
#   (32, 10)	3.0
#   (32, 11)	1.0
#   (32, 12)	3.0
#   (32, 15)	1.0
#   (32, 16)	1.0
#   (32, 17)	1.0
#   (32, 18)	1.0
#   (32, 19)	2.0
#   (32, 20)	2.0
#   (32, 21)	3.0
#   (32, 23)	1.0
#   (32, 25)	1.0
#   (32, 27)	1.0
#   (32, 28)	2.0
#   (32, 29)	2.0
#   (32, 31)	1.0
#   (32, 33)	2.0
#   (32, 36)	1.0
#   (32, 38)	1.0
#   (32, 39)	1.0
#   (32, 41)	1.0
#   (32, 42)	1.0
#   (32, 43)	1.0
#   (32, 44)	1.0
#   (32, 48)	1.0
#   (32, 50)	1.0
#   (32, 53)	1.0
#   (33, 2)	2.0
#   (33, 3)	2.0
#   (33, 4)	3.0
#   (33, 5)	1.0
#   (33, 6)	1.0
#   (33, 9)	2.0
#   (33, 10)	1.0
#   (33, 11)	1.0
#   (33, 12)	2.0
#   (33, 14)	2.0
#   (33, 15)	2.0
#   (33, 19)	1.0
#   (33, 20)	2.0
#   (33, 28)	1.0
#   (33, 29)	1.0
#   (33, 32)	1.0
#   (33, 34)	1.0
#   (33, 36)	1.0
#   (33, 38)	2.0
#   (33, 41)	1.0
#   (33, 42)	1.0
#   (33, 43)	1.0
#   (33, 44)	1.0
#   (33, 49)	1.0
#   (33, 51)	1.0
#   (34, 1)	3.0
#   (34, 2)	3.0
#   (34, 3)	3.0
#   (34, 4)	4.0
#   (34, 5)	2.0
#   (34, 7)	1.0
#   (34, 8)	2.0
#   (34, 9)	3.0
#   (34, 10)	1.0
#   (34, 11)	1.0
#   (34, 12)	2.0
#   (34, 13)	1.0
#   (34, 14)	1.0
#   (34, 15)	1.0
#   (34, 16)	1.0
#   (34, 17)	1.0
#   (34, 18)	1.0
#   (34, 19)	1.0
#   (34, 20)	1.0
#   (34, 21)	2.0
#   (34, 22)	3.0
#   (34, 25)	1.0
#   (34, 27)	2.0
#   (34, 28)	2.0
#   (34, 29)	2.0
#   (34, 30)	1.0
#   (34, 33)	2.0
#   (34, 36)	2.0
#   (34, 37)	1.0
#   (34, 38)	1.0
#   (34, 40)	2.0
#   (34, 41)	1.0
#   (34, 45)	1.0
#   (34, 46)	1.0
#   (34, 47)	2.0
#   (34, 48)	1.0
#   (34, 49)	2.0
#   (34, 50)	1.0
#   (35, 1)	4.0
#   (35, 2)	3.0
#   (35, 3)	3.0
#   (35, 4)	1.0
#   (35, 5)	3.0
#   (35, 6)	3.0
#   (35, 7)	1.0
#   (35, 9)	2.0
#   (35, 10)	1.0
#   (35, 11)	2.0
#   (35, 12)	2.0
#   (35, 13)	1.0
#   (35, 14)	2.0
#   (35, 15)	2.0
#   (35, 16)	2.0
#   (35, 17)	1.0
#   (35, 19)	1.0
#   (35, 22)	1.0
#   (35, 23)	2.0
#   (35, 24)	1.0
#   (35, 25)	1.0
#   (35, 26)	2.0
#   (35, 27)	1.0
#   (35, 28)	1.0
#   (35, 29)	1.0
#   (35, 30)	1.0
#   (35, 36)	1.0
#   (35, 38)	1.0
#   (35, 39)	1.0
#   (35, 40)	2.0
#   (35, 47)	1.0
#   (35, 51)	1.0
#   (35, 53)	1.0
#   (36, 1)	3.0
#   (36, 2)	2.0
#   (36, 3)	2.0
#   (36, 4)	2.0
#   (36, 7)	2.0
#   (36, 8)	1.0
#   (36, 9)	1.0
#   (36, 11)	4.0
#   (36, 12)	2.0
#   (36, 14)	1.0
#   (36, 15)	2.0
#   (36, 16)	1.0
#   (36, 17)	3.0
#   (36, 19)	2.0
#   (36, 20)	1.0
#   (36, 22)	1.0
#   (36, 25)	1.0
#   (36, 31)	1.0
#   (36, 32)	1.0
#   (36, 33)	2.0
#   (36, 34)	2.0
#   (36, 35)	1.0
#   (36, 37)	1.0
#   (36, 38)	2.0
#   (36, 40)	2.0
#   (36, 45)	1.0
#   (36, 46)	1.0
#   (36, 50)	2.0
#   (36, 51)	2.0
#   (38, 2)	2.0
#   (38, 3)	2.0
#   (38, 4)	2.0
#   (38, 5)	2.0
#   (38, 6)	1.0
#   (38, 7)	2.0
#   (38, 9)	1.0
#   (38, 11)	2.0
#   (38, 12)	3.0
#   (38, 14)	1.0
#   (38, 15)	2.0
#   (38, 17)	1.0
#   (38, 20)	1.0
#   (38, 27)	1.0
#   (38, 28)	1.0
#   (38, 29)	1.0
#   (38, 31)	1.0
#   (38, 32)	1.0
#   (38, 33)	2.0
#   (38, 34)	1.0
#   (38, 35)	1.0
#   (38, 36)	2.0
#   (38, 37)	1.0
#   (38, 40)	1.0
#   (38, 51)	1.0
#   (39, 1)	2.0
#   (39, 4)	2.0
#   (39, 5)	1.0
#   (39, 6)	2.0
#   (39, 7)	1.0
#   (39, 8)	1.0
#   (39, 9)	1.0
#   (39, 10)	1.0
#   (39, 11)	2.0
#   (39, 12)	1.0
#   (39, 13)	2.0
#   (39, 14)	2.0
#   (39, 15)	1.0
#   (39, 16)	1.0
#   (39, 17)	3.0
#   (39, 20)	1.0
#   (39, 21)	2.0
#   (39, 23)	3.0
#   (39, 25)	1.0
#   (39, 27)	1.0
#   (39, 28)	1.0
#   (39, 29)	1.0
#   (39, 31)	1.0
#   (39, 32)	1.0
#   (39, 33)	2.0
#   (39, 35)	1.0
#   (39, 40)	1.0
#   (39, 46)	1.0
#   (39, 48)	1.0
#   (39, 53)	1.0
#   (40, 1)	1.0
#   (40, 2)	2.0
#   (40, 3)	2.0
#   (40, 4)	3.0
#   (40, 5)	1.0
#   (40, 6)	1.0
#   (40, 7)	2.0
#   (40, 8)	1.0
#   (40, 9)	3.0
#   (40, 10)	2.0
#   (40, 11)	1.0
#   (40, 12)	1.0
#   (40, 14)	2.0
#   (40, 15)	2.0
#   (40, 18)	2.0
#   (40, 19)	1.0
#   (40, 20)	1.0
#   (40, 21)	1.0
#   (40, 22)	1.0
#   (40, 23)	1.0
#   (40, 25)	1.0
#   (40, 26)	1.0
#   (40, 28)	1.0
#   (40, 29)	1.0
#   (40, 30)	1.0
#   (40, 31)	1.0
#   (40, 34)	2.0
#   (40, 35)	1.0
#   (40, 36)	1.0
#   (40, 39)	2.0
#   (40, 41)	1.0
#   (40, 45)	1.0
#   (40, 46)	1.0
#   (40, 47)	1.0
#   (40, 48)	1.0
#   (40, 49)	1.0
#   (40, 50)	1.0
#   (41, 2)	2.0
#   (41, 3)	2.0
#   (41, 4)	1.0
#   (41, 6)	2.0
#   (41, 8)	2.0
#   (41, 9)	3.0
#   (41, 10)	2.0
#   (41, 13)	1.0
#   (41, 14)	1.0
#   (41, 16)	1.0
#   (41, 18)	2.0
#   (41, 19)	3.0
#   (41, 21)	2.0
#   (41, 22)	2.0
#   (41, 25)	1.0
#   (41, 28)	1.0
#   (41, 29)	1.0
#   (41, 31)	2.0
#   (41, 32)	1.0
#   (41, 33)	1.0
#   (41, 34)	1.0
#   (41, 37)	1.0
#   (41, 40)	1.0
#   (41, 42)	1.0
#   (41, 43)	1.0
#   (41, 44)	1.0
#   (41, 47)	1.0
#   (41, 48)	1.0
#   (41, 49)	3.0
#   (41, 50)	1.0
#   (42, 1)	1.0
#   (42, 2)	2.0
#   (42, 3)	2.0
#   (42, 4)	4.0
#   (42, 5)	2.0
#   (42, 6)	1.0
#   (42, 7)	1.0
#   (42, 8)	2.0
#   (42, 9)	2.0
#   (42, 10)	2.0
#   (42, 13)	3.0
#   (42, 14)	1.0
#   (42, 15)	2.0
#   (42, 18)	1.0
#   (42, 20)	2.0
#   (42, 21)	1.0
#   (42, 23)	1.0
#   (42, 24)	1.0
#   (42, 27)	1.0
#   (42, 28)	1.0
#   (42, 29)	1.0
#   (42, 30)	1.0
#   (42, 32)	1.0
#   (42, 33)	1.0
#   (42, 41)	1.0
#   (42, 43)	6.0
#   (42, 44)	6.0
#   (42, 47)	1.0
#   (42, 48)	2.0
#   (42, 49)	1.0
#   (43, 1)	1.0
#   (43, 2)	2.0
#   (43, 3)	2.0
#   (43, 4)	4.0
#   (43, 5)	2.0
#   (43, 6)	1.0
#   (43, 7)	1.0
#   (43, 8)	2.0
#   (43, 9)	2.0
#   (43, 10)	2.0
#   (43, 13)	3.0
#   (43, 14)	1.0
#   (43, 15)	2.0
#   (43, 18)	1.0
#   (43, 20)	2.0
#   (43, 21)	1.0
#   (43, 23)	1.0
#   (43, 24)	1.0
#   (43, 27)	1.0
#   (43, 28)	1.0
#   (43, 29)	1.0
#   (43, 30)	1.0
#   (43, 32)	1.0
#   (43, 33)	1.0
#   (43, 41)	1.0
#   (43, 42)	6.0
#   (43, 44)	6.0
#   (43, 47)	1.0
#   (43, 48)	2.0
#   (43, 49)	1.0
#   (44, 1)	1.0
#   (44, 2)	2.0
#   (44, 3)	2.0
#   (44, 4)	4.0
#   (44, 5)	2.0
#   (44, 6)	1.0
#   (44, 7)	1.0
#   (44, 8)	2.0
#   (44, 9)	2.0
#   (44, 10)	2.0
#   (44, 13)	3.0
#   (44, 14)	1.0
#   (44, 15)	2.0
#   (44, 18)	1.0
#   (44, 20)	2.0
#   (44, 21)	1.0
#   (44, 23)	1.0
#   (44, 24)	1.0
#   (44, 27)	1.0
#   (44, 28)	1.0
#   (44, 29)	1.0
#   (44, 30)	1.0
#   (44, 32)	1.0
#   (44, 33)	1.0
#   (44, 41)	1.0
#   (44, 42)	6.0
#   (44, 43)	6.0
#   (44, 47)	1.0
#   (44, 48)	2.0
#   (44, 49)	1.0
#   (46, 1)	2.0
#   (46, 2)	2.0
#   (46, 3)	2.0
#   (46, 8)	1.0
#   (46, 9)	1.0
#   (46, 10)	1.0
#   (46, 13)	1.0
#   (46, 14)	2.0
#   (46, 15)	1.0
#   (46, 17)	2.0
#   (46, 18)	1.0
#   (46, 19)	1.0
#   (46, 20)	1.0
#   (46, 21)	1.0
#   (46, 22)	2.0
#   (46, 26)	1.0
#   (46, 33)	1.0
#   (46, 34)	1.0
#   (46, 36)	1.0
#   (46, 40)	1.0
#   (47, 1)	1.0
#   (47, 2)	1.0
#   (47, 3)	1.0
#   (47, 4)	2.0
#   (47, 5)	2.0
#   (47, 6)	2.0
#   (47, 7)	2.0
#   (47, 8)	1.0
#   (47, 9)	1.0
#   (47, 10)	1.0
#   (47, 12)	1.0
#   (47, 13)	1.0
#   (47, 14)	2.0
#   (47, 16)	2.0
#   (47, 17)	1.0
#   (47, 18)	2.0
#   (47, 19)	1.0
#   (47, 21)	1.0
#   (47, 22)	1.0
#   (47, 25)	1.0
#   (47, 28)	1.0
#   (47, 29)	1.0
#   (47, 30)	2.0
#   (47, 31)	1.0
#   (47, 34)	2.0
#   (47, 35)	1.0
#   (47, 37)	1.0
#   (47, 40)	1.0
#   (47, 41)	1.0
#   (47, 42)	1.0
#   (47, 43)	1.0
#   (47, 44)	1.0
#   (47, 48)	1.0
#   (47, 49)	1.0
#   (49, 1)	1.0
#   (49, 2)	3.0
#   (49, 3)	3.0
#   (49, 4)	1.0
#   (49, 5)	1.0
#   (49, 6)	1.0
#   (49, 8)	3.0
#   (49, 9)	2.0
#   (49, 10)	1.0
#   (49, 14)	1.0
#   (49, 18)	2.0
#   (49, 19)	1.0
#   (49, 21)	2.0
#   (49, 22)	3.0
#   (49, 25)	1.0
#   (49, 27)	1.0
#   (49, 28)	2.0
#   (49, 29)	2.0
#   (49, 33)	1.0
#   (49, 34)	2.0
#   (49, 37)	1.0
#   (49, 40)	1.0
#   (49, 41)	3.0
#   (49, 42)	1.0
#   (49, 43)	1.0
#   (49, 44)	1.0
#   (49, 47)	1.0
#   (49, 48)	1.0
#   (49, 50)	1.0
#   (50, 1)	1.0
#   (50, 2)	3.0
#   (50, 3)	3.0
#   (50, 4)	1.0
#   (50, 6)	1.0
#   (50, 7)	1.0
#   (50, 8)	2.0
#   (50, 9)	1.0
#   (50, 12)	1.0
#   (50, 14)	1.0
#   (50, 16)	1.0
#   (50, 17)	1.0
#   (50, 18)	1.0
#   (50, 19)	2.0
#   (50, 21)	1.0
#   (50, 22)	1.0
#   (50, 32)	1.0
#   (50, 34)	1.0
#   (50, 36)	2.0
#   (50, 37)	1.0
#   (50, 40)	1.0
#   (50, 41)	1.0
#   (50, 45)	1.0
#   (50, 49)	1.0
#   (51, 1)	2.0
#   (51, 4)	1.0
#   (51, 5)	1.0
#   (51, 7)	1.0
#   (51, 8)	1.0
#   (51, 11)	3.0
#   (51, 12)	1.0
#   (51, 14)	2.0
#   (51, 15)	1.0
#   (51, 17)	1.0
#   (51, 18)	1.0
#   (51, 19)	1.0
#   (51, 20)	1.0
#   (51, 22)	1.0
#   (51, 23)	2.0
#   (51, 26)	1.0
#   (51, 33)	1.0
#   (51, 35)	1.0
#   (51, 36)	2.0
#   (51, 38)	1.0
#   (51, 40)	1.0
#   (52, 2)	1.0
#   (52, 3)	1.0
#   (52, 4)	1.0
#   (52, 5)	1.0
#   (52, 6)	2.0
#   (52, 7)	1.0
#   (52, 8)	1.0
#   (52, 9)	1.0
#   (52, 11)	1.0
#   (52, 12)	3.0
#   (52, 15)	1.0
#   (52, 20)	1.0
#   (52, 25)	1.0
#   (52, 26)	1.0
#   (52, 53)	1.0
#   (53, 1)	1.0
#   (53, 5)	2.0
#   (53, 6)	1.0
#   (53, 8)	1.0
#   (53, 9)	1.0
#   (53, 11)	1.0
#   (53, 12)	3.0
#   (53, 15)	1.0
#   (53, 20)	1.0
#   (53, 21)	1.0
#   (53, 22)	1.0
#   (53, 23)	2.0
#   (53, 25)	2.0
#   (53, 26)	1.0
#   (53, 32)	1.0
#   (53, 33)	1.0
#   (53, 35)	1.0
#   (53, 39)	1.0
#   (53, 52)	1.0

# %% [markdown]
# # TSNE SUR DONNEES BRUTES

# %%
# calculer matrice et enlever diagonale (val à 0) trier chaque ligne en décroissant 
# et prendr les 4 premiers (vérifier si il y a des voisins lus proche > 1)
# a faire sur donnée centrée 
# -------------- DONE --------------
# regarder sur les données d'Oniris
# refaire 8-9 visu pr tsne avec données brutes (centré) en faisant varié les params 
# faire un cosinus sur les 150 premieres dimensions de l'ACP (prendre les n dimensions représentant 90% de l'info + faire tsn-e sur cette matrice)
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 10)

cooc_mat_cosine = cosine_distances(cooc_mat)

for row in cooc_mat_cosine:
    t = np.array(row)
    indices = t.argsort()
    indices = indices[t[indices] > 0]
    print([t[indices[0]],t[indices[1]],t[indices[2]],t[indices[3]]])

tsne = TSNE(n_components=2,metric='precomputed',verbose=2,n_iter=2000,perplexity=20,early_exaggeration = 12,learning_rate=10)
X_embedded = tsne.fit_transform(cooc_mat_cosine)


df_subset = {} 
df_subset['tsne-2d-one'] = X_embedded[:,0]
df_subset['tsne-2d-two'] = X_embedded[:,1]
plt.figure(figsize=(16,10))
p1 = sns.scatterplot(X_embedded[:,0], X_embedded[:,1], legend='full', palette=palette)
for line in range(0,cooc_mat.shape[0]):
     p1.text(df_subset['tsne-2d-one'][line]+0.01, df_subset['tsne-2d-two'][line], 
     headerText[line], horizontalalignment='left', 
     size='small',fontsize=7, color='black', weight='semibold')
# Out:
# [1.0, 1.0, 1.0, 1.0]
# [0.1633988, 0.21669668, 0.2206049, 0.22086221]
# [0.19946933, 0.23796195, 0.24057984, 0.24302131]
# [0.2129786, 0.21655655, 0.2458815, 0.251684]
# [0.19283038, 0.19398457, 0.20835918, 0.21797585]
# [0.23311317, 0.263272, 0.2920506, 0.31294006]
# [0.17086619, 0.188945, 0.19375712, 0.19398457]
# [0.206132, 0.21243751, 0.21293145, 0.2212084]
# [0.17253971, 0.19871557, 0.2206049, 0.2210592]
# [0.1633988, 0.17253971, 0.17360842, 0.18343079]
# [0.17086619, 0.17360842, 0.18788576, 0.21590728]
# [0.19456238, 0.206132, 0.22353685, 0.24176985]
# [0.20343632, 0.210047, 0.2219193, 0.22353685]
# [0.2162363, 0.21797585, 0.21881968, 0.25249135]
# [0.26590484, 0.28335023, 0.2886243, 0.29488987]
# [0.19283038, 0.19375712, 0.19456238, 0.199534]
# [0.2212084, 0.22220558, 0.22511631, 0.23218727]
# [0.21225804, 0.22855008, 0.24731857, 0.25070834]
# [0.19954318, 0.23072928, 0.2322833, 0.23528087]
# [0.18343079, 0.21225804, 0.22564453, 0.23528087]
# [0.21727878, 0.2369417, 0.24565327, 0.25666904]
# [0.19532162, 0.20719671, 0.22178394, 0.22270554]
# [0.19532162, 0.23109436, 0.25556254, 0.27445948]
# [0.24906075, 0.25030202, 0.25784022, 0.27304703]
# [0.21220106, 0.21319139, 0.22220558, 0.23024887]
# [0.24611181, 0.25697458, 0.27040905, 0.30432343]
# [0.24416125, 0.27260196, 0.27827692, 0.27977997]
# [0.23531336, 0.23531336, 0.24969053, 0.2566613]
# [0.23531336, 0.24628323, 0.25956762, 0.26640034]
# [0.23531336, 0.24628323, 0.25956762, 0.26640034]
# [0.2162363, 0.23218727, 0.23311317, 0.2510916]
# [0.348737, 0.3488781, 0.35845888, 0.3745126]
# [0.19026822, 0.24611181, 0.25956762, 0.25956762]
# [0.2578439, 0.26454347, 0.27442634, 0.2817124]
# [0.2149449, 0.21590728, 0.22178394, 0.23915076]
# [0.20343632, 0.21319139, 0.23351479, 0.23469603]
# [0.29818505, 0.29935104, 0.2997082, 0.31188983]
# [1.0, 1.0, 1.0, 1.0]
# [0.28181523, 0.28550428, 0.2942555, 0.29935104]
# [0.28759283, 0.33029497, 0.33903712, 0.34667832]
# [0.18788576, 0.199534, 0.20410705, 0.2167244]
# [0.24444437, 0.24952126, 0.2777652, 0.30269837]
# [0.24000007, 0.24000007, 0.3297333, 0.33917278]
# [0.24000007, 0.24000007, 0.3297333, 0.33917278]
# [0.24000007, 0.24000007, 0.3297333, 0.33917278]
# [1.0, 1.0, 1.0, 1.0]
# [0.28159082, 0.3049144, 0.31163883, 0.3157894]
# [0.21881968, 0.24607563, 0.25464195, 0.2586758]
# [1.0, 1.0, 1.0, 1.0]
# [0.22294939, 0.24484599, 0.24628323, 0.24628323]
# [0.28135186, 0.28159082, 0.2830614, 0.28571427]
# [0.3250698, 0.33499497, 0.33692032, 0.33928162]
# [0.3135935, 0.31640095, 0.3266195, 0.3461538]
# [0.3135935, 0.33576572, 0.37401927, 0.40091527]
# [t-SNE] Computing 53 nearest neighbors...
# [t-SNE] Indexed 54 samples in 0.000s...
# [t-SNE] Computed neighbors for 54 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 54 / 54
# [t-SNE] Mean sigma: 0.183230
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = 44.9051323, gradient norm = 0.7134029 (50 iterations in 0.017s)
# [t-SNE] Iteration 100: error = 45.3052368, gradient norm = 0.7864186 (50 iterations in 0.012s)
# [t-SNE] Iteration 150: error = 47.0137177, gradient norm = 0.7674627 (50 iterations in 0.012s)
# [t-SNE] Iteration 200: error = 46.0873032, gradient norm = 1.0489334 (50 iterations in 0.013s)
# [t-SNE] Iteration 250: error = 47.8480949, gradient norm = 1.0582359 (50 iterations in 0.012s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 47.848095
# [t-SNE] Iteration 300: error = 0.7612328, gradient norm = 0.0062437 (50 iterations in 0.011s)
# [t-SNE] Iteration 350: error = 0.3597710, gradient norm = 0.0046640 (50 iterations in 0.011s)
# [t-SNE] Iteration 400: error = 0.3400435, gradient norm = 0.0021223 (50 iterations in 0.011s)
# [t-SNE] Iteration 450: error = 0.2828784, gradient norm = 0.0025332 (50 iterations in 0.010s)
# [t-SNE] Iteration 500: error = 0.2829794, gradient norm = 0.0005911 (50 iterations in 0.010s)
# [t-SNE] Iteration 550: error = 0.2818751, gradient norm = 0.0007017 (50 iterations in 0.010s)
# [t-SNE] Iteration 600: error = 0.2825678, gradient norm = 0.0003132 (50 iterations in 0.013s)
# [t-SNE] Iteration 650: error = 0.2827275, gradient norm = 0.0004472 (50 iterations in 0.009s)
# [t-SNE] Iteration 700: error = 0.2820508, gradient norm = 0.0005792 (50 iterations in 0.011s)
# [t-SNE] Iteration 750: error = 0.2817729, gradient norm = 0.0004144 (50 iterations in 0.010s)
# [t-SNE] Iteration 800: error = 0.2822729, gradient norm = 0.0003269 (50 iterations in 0.013s)
# [t-SNE] Iteration 850: error = 0.2824152, gradient norm = 0.0008582 (50 iterations in 0.011s)
# [t-SNE] Iteration 900: error = 0.2822742, gradient norm = 0.0003367 (50 iterations in 0.010s)
# [t-SNE] Iteration 950: error = 0.2817166, gradient norm = 0.0006844 (50 iterations in 0.012s)
# [t-SNE] Iteration 1000: error = 0.2822112, gradient norm = 0.0003507 (50 iterations in 0.010s)
# [t-SNE] Iteration 1050: error = 0.2820808, gradient norm = 0.0007895 (50 iterations in 0.011s)
# [t-SNE] Iteration 1100: error = 0.2822596, gradient norm = 0.0005022 (50 iterations in 0.010s)
# [t-SNE] Iteration 1150: error = 0.2822304, gradient norm = 0.0003254 (50 iterations in 0.011s)
# [t-SNE] Iteration 1200: error = 0.2823265, gradient norm = 0.0004067 (50 iterations in 0.011s)
# [t-SNE] Iteration 1250: error = 0.2822452, gradient norm = 0.0003491 (50 iterations in 0.011s)
# [t-SNE] Iteration 1300: error = 0.2822378, gradient norm = 0.0003555 (50 iterations in 0.010s)
# [t-SNE] Iteration 1300: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1300 iterations: 0.282238

# %% [markdown]
# # TSNE SUR DONNEES CENTREE REDUITE

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler(with_mean=False)
Z = sc.fit_transform(cooc_mat)

sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 10)

cooc_mat_cosine = cosine_distances(Z)


listPerplexity = [10,5,20]
listLearningRate = [12,6]
listEarlyExa = [10,20]


for row in cooc_mat_cosine:
    t = np.array(row)
    indices = t.argsort()
    indices = indices[t[indices] > 0]
    print([t[indices[0]],t[indices[1]],t[indices[2]],t[indices[3]]])

tsne = TSNE(n_components=2,metric='precomputed',verbose=2,n_iter=2000,perplexity=20,early_exaggeration = 12,learning_rate=10)
X_embedded = tsne.fit_transform(cooc_mat_cosine)
df_subset = {} 
df_subset['tsne-2d-one'] = X_embedded[:,0]
df_subset['tsne-2d-two'] = X_embedded[:,1]
plt.figure(figsize=(16,10))

p1 = sns.scatterplot(X_embedded[:,0], X_embedded[:,1], legend='full', palette=palette)
index = 0
for line in range(0,Z.shape[0]):
    if index%2 == 0:
        decalage = 0.03
    else:
        decalage = -0.03
     p1.text(df_subset['tsne-2d-one'][line]+decalage, df_subset['tsne-2d-two'][line]+decalage, 
     headerText[line], horizontalalignment='left', 
     size='small', color='black', weight='semibold')
    index+=1
# Out:
# [1.0, 1.0, 1.0, 1.0]
# [0.2262975, 0.24587798, 0.25716418, 0.25895423]
# [0.16559923, 0.20543122, 0.21077722, 0.2262975]
# [0.17894858, 0.20543122, 0.23540759, 0.24013174]
# [0.19622374, 0.22608387, 0.22947967, 0.22973084]
# [0.23873013, 0.28693157, 0.3398776, 0.3556534]
# [0.212538, 0.22716975, 0.23313671, 0.24052477]
# [0.22608387, 0.2401784, 0.25396687, 0.26052105]
# [0.18388116, 0.21077722, 0.23702335, 0.23948658]
# [0.16559923, 0.17894858, 0.18388116, 0.22192156]
# [0.212538, 0.22192156, 0.24048012, 0.24701005]
# [0.20441419, 0.24157274, 0.25396687, 0.2775066]
# [0.24157274, 0.24668998, 0.27035534, 0.27496088]
# [0.22973084, 0.24838132, 0.26036674, 0.26908427]
# [0.34278882, 0.3443421, 0.3473423, 0.35611874]
# [0.19622374, 0.20441419, 0.24052477, 0.24668998]
# [0.2632386, 0.26467144, 0.28510737, 0.30964482]
# [0.25895423, 0.26921457, 0.2807715, 0.28277105]
# [0.22478229, 0.23702335, 0.2443707, 0.25048047]
# [0.22609466, 0.25773466, 0.26095766, 0.27660662]
# [0.25764102, 0.2775066, 0.29212165, 0.33159083]
# [0.21727258, 0.23948658, 0.2473666, 0.2745306]
# [0.21727258, 0.24729967, 0.27512878, 0.28934008]
# [0.2803266, 0.2913049, 0.29651535, 0.32261157]
# [0.26036674, 0.29946673, 0.30043256, 0.30964482]
# [0.27496088, 0.28289455, 0.29584253, 0.30216372]
# [0.33706123, 0.34028244, 0.3447479, 0.34588856]
# [0.2512868, 0.2512868, 0.31711262, 0.32449293]
# [0.23188347, 0.2512868, 0.2768293, 0.28094244]
# [0.23188347, 0.2512868, 0.2768293, 0.28094244]
# [0.23873013, 0.26467144, 0.26829588, 0.29692453]
# [0.3092491, 0.36109632, 0.36236274, 0.37036353]
# [0.25990236, 0.30216372, 0.3169557, 0.3169557]
# [0.36401063, 0.38805014, 0.38906252, 0.39408797]
# [0.23540759, 0.2546758, 0.26824665, 0.28766203]
# [0.28205866, 0.2827145, 0.29214168, 0.31270283]
# [0.3256122, 0.32709086, 0.36689925, 0.38131136]
# [1.0, 1.0, 1.0, 1.0]
# [0.3120973, 0.3256122, 0.34784037, 0.35020185]
# [0.3406918, 0.35929823, 0.36108458, 0.36506784]
# [0.2409032, 0.2511025, 0.26306337, 0.26921457]
# [0.2636212, 0.32849073, 0.33061433, 0.33442938]
# [0.2427072, 0.2427072, 0.3749526, 0.3764854]
# [0.2427072, 0.2427072, 0.3749526, 0.3764854]
# [0.2427072, 0.2427072, 0.3749526, 0.3764854]
# [1.0, 1.0, 1.0, 1.0]
# [0.35334307, 0.3843971, 0.39009792, 0.39537436]
# [0.26908427, 0.28879952, 0.29655337, 0.29721498]
# [1.0, 1.0, 1.0, 1.0]
# [0.2745306, 0.29172522, 0.3032856, 0.30659366]
# [0.2883044, 0.35334307, 0.354317, 0.35746652]
# [0.32929856, 0.34281242, 0.3709519, 0.3712138]
# [0.42969453, 0.4354189, 0.43602115, 0.43689883]
# [0.34029734, 0.35451478, 0.430556, 0.43602115]
# [t-SNE] Computing 53 nearest neighbors...
# [t-SNE] Indexed 54 samples in 0.000s...
# [t-SNE] Computed neighbors for 54 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 54 / 54
# [t-SNE] Mean sigma: 0.198724
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 44.0533867, gradient norm = 1.3640504 (50 iterations in 0.021s)
# [t-SNE] Iteration 100: error = 43.6913757, gradient norm = 1.2841612 (50 iterations in 0.018s)
# [t-SNE] Iteration 150: error = 42.3365593, gradient norm = 1.0817879 (50 iterations in 0.019s)
# [t-SNE] Iteration 200: error = 39.8009872, gradient norm = 1.2936027 (50 iterations in 0.018s)
# [t-SNE] Iteration 250: error = 44.7399368, gradient norm = 0.5572672 (50 iterations in 0.019s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 44.739937
# [t-SNE] Iteration 300: error = 0.2960123, gradient norm = 0.0091462 (50 iterations in 0.016s)
# [t-SNE] Iteration 350: error = 0.2674983, gradient norm = 0.0007929 (50 iterations in 0.015s)
# [t-SNE] Iteration 400: error = 0.2660684, gradient norm = 0.0002479 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.2660227, gradient norm = 0.0001756 (50 iterations in 0.015s)
# [t-SNE] Iteration 500: error = 0.2659956, gradient norm = 0.0002619 (50 iterations in 0.015s)
# [t-SNE] Iteration 550: error = 0.2660128, gradient norm = 0.0001989 (50 iterations in 0.018s)
# [t-SNE] Iteration 600: error = 0.2659855, gradient norm = 0.0002464 (50 iterations in 0.017s)
# [t-SNE] Iteration 650: error = 0.2660260, gradient norm = 0.0001941 (50 iterations in 0.017s)
# [t-SNE] Iteration 700: error = 0.2659875, gradient norm = 0.0002465 (50 iterations in 0.017s)
# [t-SNE] Iteration 750: error = 0.2659843, gradient norm = 0.0002302 (50 iterations in 0.015s)
# [t-SNE] Iteration 800: error = 0.2660145, gradient norm = 0.0002170 (50 iterations in 0.015s)
# [t-SNE] Iteration 850: error = 0.2657103, gradient norm = 0.0002660 (50 iterations in 0.014s)
# [t-SNE] Iteration 900: error = 0.2653540, gradient norm = 0.0002124 (50 iterations in 0.016s)
# [t-SNE] Iteration 950: error = 0.2656764, gradient norm = 0.0003856 (50 iterations in 0.014s)
# [t-SNE] Iteration 1000: error = 0.2649101, gradient norm = 0.0003794 (50 iterations in 0.016s)
# [t-SNE] Iteration 1050: error = 0.2595797, gradient norm = 0.0004161 (50 iterations in 0.016s)
# [t-SNE] Iteration 1100: error = 0.2653355, gradient norm = 0.0003736 (50 iterations in 0.016s)
# [t-SNE] Iteration 1150: error = 0.2541336, gradient norm = 0.0005045 (50 iterations in 0.018s)
# [t-SNE] Iteration 1200: error = 0.2533685, gradient norm = 0.0003142 (50 iterations in 0.016s)
# [t-SNE] Iteration 1250: error = 0.2407468, gradient norm = 0.0008609 (50 iterations in 0.016s)
# [t-SNE] Iteration 1300: error = 0.2530118, gradient norm = 0.0006541 (50 iterations in 0.017s)
# [t-SNE] Iteration 1350: error = 0.2534110, gradient norm = 0.0003181 (50 iterations in 0.016s)
# [t-SNE] Iteration 1400: error = 0.2534308, gradient norm = 0.0004417 (50 iterations in 0.015s)
# [t-SNE] Iteration 1450: error = 0.2386821, gradient norm = 0.0004428 (50 iterations in 0.015s)
# [t-SNE] Iteration 1500: error = 0.2383851, gradient norm = 0.0004361 (50 iterations in 0.014s)
# [t-SNE] Iteration 1550: error = 0.2381852, gradient norm = 0.0004235 (50 iterations in 0.017s)
# [t-SNE] Iteration 1600: error = 0.2381248, gradient norm = 0.0002460 (50 iterations in 0.015s)
# [t-SNE] Iteration 1650: error = 0.2380683, gradient norm = 0.0002017 (50 iterations in 0.015s)
# [t-SNE] Iteration 1700: error = 0.2380551, gradient norm = 0.0002304 (50 iterations in 0.014s)
# [t-SNE] Iteration 1750: error = 0.2377535, gradient norm = 0.0004953 (50 iterations in 0.016s)
# [t-SNE] Iteration 1800: error = 0.2384349, gradient norm = 0.0002519 (50 iterations in 0.017s)
# [t-SNE] Iteration 1850: error = 0.2385116, gradient norm = 0.0003921 (50 iterations in 0.015s)
# [t-SNE] Iteration 1900: error = 0.2382060, gradient norm = 0.0001750 (50 iterations in 0.014s)
# [t-SNE] Iteration 1950: error = 0.2380200, gradient norm = 0.0003566 (50 iterations in 0.017s)
# [t-SNE] Iteration 2000: error = 0.2384365, gradient norm = 0.0002903 (50 iterations in 0.016s)
# [t-SNE] KL divergence after 2000 iterations: 0.238437

# %%
word = 'boise'
assert word in tokenizer.word_index, 'Word {} is not in the tokenizer'.format(word)
assert tokenizer.word_index[word] <= v_size, 'The word {} is an out of vocabuary word. Please try something else'.format(word)

rev_word_index = dict(zip(tokenizer.word_index.values(), tokenizer.word_index.keys()))

cooc_vec = np.array(cooc_mat.getrow(tokenizer.word_index[word]).todense()).ravel()
max_ind = np.argsort(cooc_vec)[-25:]
#print(max_ind)
plt.figure(figsize=(16,8))
plt.bar(np.arange(0, 25), cooc_vec[max_ind])
plt.xticks(ticks=np.arange(0, 25), labels=[rev_word_index[i] for i in max_ind], rotation=60)
# Out:
# ([<matplotlib.axis.XTick at 0x2a429efc5c0>,
#   <matplotlib.axis.XTick at 0x2a428da4208>,
#   <matplotlib.axis.XTick at 0x2a428de2d68>,
#   <matplotlib.axis.XTick at 0x2a429fd74e0>,
#   <matplotlib.axis.XTick at 0x2a429fd79e8>,
#   <matplotlib.axis.XTick at 0x2a429fd7f60>,
#   <matplotlib.axis.XTick at 0x2a429fd77f0>,
#   <matplotlib.axis.XTick at 0x2a429fde668>,
#   <matplotlib.axis.XTick at 0x2a429fdec18>,
#   <matplotlib.axis.XTick at 0x2a429fe5208>,
#   <matplotlib.axis.XTick at 0x2a429fe5748>,
#   <matplotlib.axis.XTick at 0x2a429fe5cc0>,
#   <matplotlib.axis.XTick at 0x2a429fea278>,
#   <matplotlib.axis.XTick at 0x2a429fea7f0>,
#   <matplotlib.axis.XTick at 0x2a429fead68>,
#   <matplotlib.axis.XTick at 0x2a429ff2320>,
#   <matplotlib.axis.XTick at 0x2a429fea198>,
#   <matplotlib.axis.XTick at 0x2a429fe52b0>,
#   <matplotlib.axis.XTick at 0x2a429ff2550>,
#   <matplotlib.axis.XTick at 0x2a429ff2d30>,
#   <matplotlib.axis.XTick at 0x2a429ff92e8>,
#   <matplotlib.axis.XTick at 0x2a429ff9860>,
#   <matplotlib.axis.XTick at 0x2a429ff9dd8>,
#   <matplotlib.axis.XTick at 0x2a429fff390>,
#   <matplotlib.axis.XTick at 0x2a429fff908>],
#  <a list of 25 Text xticklabel objects>)

# %%
def create_glove_model(v_size):    
    w_i = Input(shape=(1,))
    w_j = Input(shape=(1,))

    emb_i = Flatten()(Embedding(v_size, 5, input_length=1)(w_i))
    emb_j = Flatten()(Embedding(v_size, 5, input_length=1)(w_j))

    ij_dot = Dot(axes=-1)([emb_i,emb_j])
    
    b_i = Flatten()(
        Embedding(v_size, 1, input_length=1)(w_i)
    )
    b_j = Flatten()(
        Embedding(v_size, 1, input_length=1)(w_j)
    )

    pred = Add()([ij_dot, b_i, b_j])

    def glove_loss(y_true, y_pred):
        return K.sum(
            K.pow((y_true-1)/100.0, 0.75)*K.square(y_pred - K.log(y_true))
        )

    model = Model(inputs=[w_i, w_j],outputs=pred)
    model.compile(loss=glove_loss, optimizer =Adam(lr=0.0001))
    return model

# %%
K.clear_session()
model = create_glove_model(v_size)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 5)         270         input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 5)         270         input_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 5)            0           embedding[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 5)            0           embedding_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 1)         54          input_1[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 1)         54          input_2[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1)            0           flatten[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1)            0           embedding_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1)            0           embedding_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           dot[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# ==================================================================================================
# Total params: 648
# Trainable params: 648
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
cooc_mat = load_npz(os.path.join('datasets','cooc_mat.npz'))
batch_size =20
copy_docs = list(docs)
index2word = dict(zip(tokenizer.word_index.values(), tokenizer.word_index.keys()))
""" Each epoch """
for ep in range(10):
    
    #valid_words = get_valid_words(docs, 20, tokenizer)
    
    random.shuffle(copy_docs)
    losses = []
    """ Each document (i.e. movie plot) """
    for doc in copy_docs:
        
        seq = tokenizer.texts_to_sequences([doc])[0]

        """ Getting skip-gram data """
        # Negative samples are automatically sampled by tf loss function
        wpairs, labels = skipgrams(
            sequence=seq, vocabulary_size=v_size, negative_samples=0.0, shuffle=True
        )
        
        if len(wpairs)==0:
            continue

        sg_in, sg_out = zip(*wpairs)
        sg_in, sg_out = np.array(sg_in).reshape(-1,1), np.array(sg_out).reshape(-1,1)
        x_ij = np.array(cooc_mat[sg_in[:,0], sg_out[:,0]]).reshape(-1,1) + 1
        
        assert np.all(np.array(labels)==1)
        assert x_ij.shape[0] == sg_in.shape[0], 'X_ij {} shape does not sg_in {}'.format(x_ij.shape, sg_in.shape)
        """ For each batch in the dataset """
        model.fit([sg_in, sg_out], x_ij, batch_size = batch_size, epochs=1, verbose=0)
        l = model.evaluate([sg_in, sg_out], x_ij, batch_size=batch_size, verbose=0)
        losses.append(l)
    print('Loss in epoch {}: {}'.format(ep, np.mean(losses)))
# Out:
# C:\Users\Sebastien\Anaconda3\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Loss in epoch 0: 2.31108364400875
# Loss in epoch 1: 2.2698290830445624
# Loss in epoch 2: 2.2546128549030793
# Loss in epoch 3: 2.2088261839592356
# Loss in epoch 4: 2.1511437643896665
# Loss in epoch 5: 2.1285812770367354
# Loss in epoch 6: 2.1081663442033984
# Loss in epoch 7: 2.038814363798862
# Loss in epoch 8: 2.01703369959494
# Loss in epoch 9: 1.9518472818636654

# %%
def save_embeddings(model,save_dir, tok, v_size):
    """ Saving data to disk """
    
    # We need to add the 0th index to word list manually
    word_list = ["RESERVED"]+[tok.index_word[w_i] for w_i in range(1,v_size)]
    emb_w_df = None
    for layer in model.layers:
        if 'embedding' == layer.name or 'embedding_1' == layer.name:
            if emb_w_df is None:
                emb_w_df = pd.DataFrame(layer.get_weights()[0])
            else:
                emb_w_df += layer.get_weights()[0]
    
    emb_w_df.insert(0, "word", word_list)
            
    emb_w_df.to_csv(
        os.path.join(save_dir, 'embeddings_w_Oniris.csv'), index=False, header=None
    )
    
save_embeddings(model, 'datasets', tokenizer, v_size)
model.save('glove_model_Oniris.h5')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-4c7b3625c7a3> in <module>
#      19
#      20 save_embeddings(model, 'datasets', tokenizer, v_size)
# ---> 21 model.save('glove_model_Oniris.h5')
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     973     """
#     974     saving.save_model(self, filepath, overwrite, include_optimizer, save_format,
# --> 975                       signatures, options)
#     976
#     977   def save_weights(self, filepath, overwrite=True, save_format=None):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     110           'or using `save_weights`.')
#     111     hdf5_format.save_model_to_hdf5(
# --> 112         model, filepath, overwrite, include_optimizer)
#     113   else:
#     114     saved_model_save.save(model, filepath, overwrite, include_optimizer,
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     113     if (include_optimizer and model.optimizer and
#     114         not isinstance(model.optimizer, optimizers.TFOptimizer)):
# --> 115       save_optimizer_weights_to_hdf5_group(f, model.optimizer)
#     116
#     117     f.flush()
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in save_optimizer_weights_to_hdf5_group(hdf5_group, optimizer)
#     585     for name, val in zip(weight_names, weight_values):
#     586       param_dset = weights_group.create_dataset(
# --> 587           name, val.shape, dtype=val.dtype)
#     588       if not val.shape:
#     589         # scalar
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\group.py in create_dataset(self, name, shape, dtype, data, **kwds)
#     137             dset = dataset.Dataset(dsid)
#     138             if name is not None:
# --> 139                 self[name] = dset
#     140             return dset
#     141
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\group.py in __setitem__(self, name, obj)
#     369
#     370             if isinstance(obj, HLObject):
# --> 371                 h5o.link(obj.id, self.id, name, lcpl=lcpl, lapl=self._lapl)
#     372
#     373             elif isinstance(obj, SoftLink):
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5o.pyx in h5py.h5o.link()
#
# RuntimeError: Unable to create link (name already exists)

# %%
def get_valid_words(docs, size, tok):
    """ Get a random set of words to check the embeddings """
    np.random.seed(120)
    valid_docs = np.random.choice(docs, size=size//2)
    valid_words = []
    for doc in valid_docs:
        np.random.seed(100)
        words = np.random.choice(tok.texts_to_sequences([doc])[0],size=2)
        valid_words.extend(words)
        
    return valid_words
        
valid_words = get_valid_words(docs, 10, tokenizer)
def load_embeddings(filename):
    print('Loading the word embeddings from the disk')
    embed_df = pd.read_csv(filename, index_col=False, header=None)
    embed_df = embed_df.set_index(0)
    print('Embedding shape: {}'.format(embed_df.shape))
    embed_mat = embed_df.values
    words = embed_df.index.values
    return embed_mat, words

def get_cosine_sim(emb, valid_words, top_k):
    norm = np.sqrt(np.sum(emb**2,axis=1,keepdims=True))
    norm_emb = emb/norm
    in_emb = norm_emb[valid_words,:]
    similarity = np.dot(in_emb, np.transpose(norm_emb))
    sorted_ind = np.argsort(-similarity, axis=1)[:,1:top_k+1]
    return sorted_ind, valid_words

embed_mat, words = load_embeddings(os.path.join('datasets','embeddings_w_Oniris.csv'))
print(embed_mat)
print(words)
best_ids, wids = get_cosine_sim(embed_mat, valid_words, 5)
pd.Series(words).to_csv(os.path.join('datasets','index2word_Oniris.csv'))
for w, bi in zip(wids, best_ids):
    print("{}: {}".format(words[w], ', '.join(words[bii] for bii in bi)))
# Out:
# Loading the word embeddings from the disk
# Embedding shape: (54, 5)
# [[ 0.06364965 -0.04530773  0.03180134  0.00221772  0.04743914]
#  [ 0.16137311 -0.19799846  0.13391967  0.07615978 -0.12130779]
#  [ 0.14725356 -0.14890432  0.10948136  0.14911956 -0.10289931]
#  [ 0.01653739 -0.19001457  0.11655463  0.05744162 -0.16543777]
#  [ 0.12196715 -0.18936518  0.04667458  0.07302609 -0.11486654]
#  [ 0.0872198  -0.10745113  0.09115537  0.01204581 -0.03189233]
#  [ 0.15329829 -0.14902553  0.10141634  0.13115619 -0.07864884]
#  [ 0.11382046 -0.1151584   0.08892703  0.03228037 -0.04379581]
#  [ 0.123267   -0.15496498  0.07911326  0.11386937 -0.02358235]
#  [ 0.14500779 -0.15678245  0.04459293  0.17737436 -0.06149681]
#  [ 0.07256588 -0.07874122  0.0222195   0.08550511 -0.13817099]
#  [ 0.15873417 -0.128143    0.11273403  0.09267636 -0.06666758]
#  [ 0.17807926 -0.21557908  0.13240111  0.1140751  -0.11949277]
#  [ 0.05768358 -0.04631754 -0.00867845  0.11943018 -0.04760486]
#  [ 0.01705119 -0.13240853  0.11130638  0.05411661 -0.1410251 ]
#  [ 0.13423127 -0.08030371  0.0240058   0.1203109  -0.10044838]
#  [ 0.08366136 -0.13457617  0.08915067  0.06560798 -0.11251996]
#  [ 0.08281796 -0.1492024   0.08927453  0.03124772 -0.09696624]
#  [ 0.15987347 -0.13461952  0.09369674  0.06187839 -0.0462522 ]
#  [ 0.04574137 -0.12118833  0.04614404  0.05071299 -0.09498451]
#  [ 0.08287609 -0.11660874  0.12736356  0.06927821 -0.08139454]
#  [ 0.11131086 -0.06539444  0.0965809   0.09688842 -0.10513108]
#  [ 0.08243947 -0.09847168  0.02168853  0.09322819 -0.06063371]
#  [ 0.16033858 -0.11408378  0.1165112   0.06586628 -0.07289324]
#  [ 0.10603318 -0.139916    0.04210347  0.12905961 -0.0305351 ]
#  [ 0.08281903 -0.08751776  0.07027576  0.0458226  -0.01962499]
#  [ 0.06495398 -0.07816316  0.13537452  0.14585412 -0.12467538]
#  [ 0.01928495 -0.0903656  -0.0291763   0.06777468 -0.04881647]
#  [ 0.0413105  -0.1304434  -0.00594989  0.10102279 -0.05983521]
#  [ 0.09486485 -0.14031151  0.1184786   0.05391274  0.00241484]
#  [ 0.05834706 -0.13562521 -0.01431091  0.02424958 -0.10261563]
#  [ 0.10926776 -0.03159513  0.10651556  0.02908517 -0.14179188]
#  [ 0.04219301 -0.13477808  0.04587408  0.0662375  -0.09129612]
#  [ 0.02222557 -0.07545044  0.11724183  0.0270821  -0.10220926]
#  [ 0.13267162 -0.12081553  0.10047497  0.07691713 -0.09752013]
#  [-0.01423913 -0.08097636  0.06571636  0.11869443 -0.05192854]
#  [ 0.05394472 -0.13803902  0.03595529  0.00083226 -0.11093398]
#  [ 0.05840001 -0.0697019   0.06903274 -0.07291584 -0.04724777]
#  [ 0.0485999  -0.07591134  0.06634783  0.06291491 -0.03595387]
#  [ 0.10152681 -0.03759204  0.03784699  0.04675715 -0.13756092]
#  [ 0.06733303 -0.10034291  0.00444362  0.03379179 -0.10661106]
#  [ 0.07509761 -0.0811755  -0.05816041  0.05398324 -0.03801445]
#  [-0.01108322 -0.00203352 -0.06413183  0.09288982  0.03940228]
#  [ 0.01367508 -0.01252836 -0.04177642  0.09566693 -0.01683326]
#  [-0.03660781 -0.02033482 -0.05834639  0.04896976  0.02174465]
#  [-0.01265772 -0.04373498  0.01854518  0.03088765 -0.09734672]
#  [ 0.05185956 -0.13277227  0.06781643  0.02904611 -0.0458555 ]
#  [ 0.02628132 -0.08880874  0.07917223  0.00235035 -0.06647199]
#  [ 0.04754808 -0.02073789 -0.02611968  0.05708487  0.00723425]
#  [ 0.08726276 -0.03822711 -0.01646185  0.10688773  0.00992883]
#  [-0.00326447 -0.13811378  0.10079342  0.01730817 -0.10848735]
#  [ 0.0699335  -0.07917958  0.13264385 -0.00079358 -0.05121643]
#  [ 0.0749118  -0.04544026  0.04240346  0.07567233 -0.11057827]
#  [ 0.14162937 -0.05343817  0.05877007  0.03694764 -0.0206527 ]]
# ['RESERVED' 'fermentaire' 'cuir' 'thiolvegetal' 'anise' 'vanille' 'doux'
#  'mineral' 'epice' 'beurre' 'alcool' 'inconnu' 'fruitssecs' 'champignon'
#  'vegetalsec' 'floral' 'géranium' 'empyreumatique' 'chimique' 'autre'
#  'rose' 'noyaudecerise' 'agrumes' 'lactone' 'fruitsnoirs' 'levure'
#  'métallique' 'ànoyaux' 'animal' 'malte' 'amandeamère' 'fruitsexotiques'
#  'boise' 'soufre' 'fruitscuits' 'amylique' 'caramel' 'vinaigre'
#  'fruitsjaunes' 'pharmaceutique' 'lactique' 'fruitsàpépins' 'aldehyde'
#  'moisi' 'terreux' 'vegetalvert' 'pieds' 'menthe' 'violette' 'fruite'
#  'pommedeterre' 'fumé' 'légumescuits' 'pyrazique']
# mineral: chimique, vanille, levure, lactone, fermentaire
# mineral: chimique, vanille, levure, lactone, fermentaire
# fruitsjaunes: rose, cuir, doux, fruitssecs, levure
# fruitsjaunes: rose, cuir, doux, fruitssecs, levure
# thiolvegetal: vegetalsec, pommedeterre, autre, menthe, boise
# thiolvegetal: vegetalsec, pommedeterre, autre, menthe, boise
# agrumes: beurre, fruitsnoirs, cuir, floral, doux
# agrumes: beurre, fruitsnoirs, cuir, floral, doux
# agrumes: beurre, fruitsnoirs, cuir, floral, doux
# agrumes: beurre, fruitsnoirs, cuir, floral, doux
# C:\Users\Sebastien\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 10)
def getCosineMatrix(emb):
    matrix = pairwise_distances(emb, metric='cosine', n_jobs=-1)
    return np.abs(matrix)
embed_mat, words = load_embeddings(os.path.join('datasets','embeddings_w_Oniris.csv'))
cosine_matrix = getCosineMatrix(embed_mat)

cosine_matrix2 = cosine_distances(embed_mat)
print(cosine_matrix2)
#print(cosine_matrix)
print(cosine_matrix.shape)

#tsne = TSNE(n_components=2,metric='precomputed',verbose=2,n_iter=2000,perplexity=15,early_exaggeration = 6)

listBatch = [20,30,40]
listPerplexity = [10,5,20]
listLearningRate = [12,6]
listEarlyExa = [10,20]

tsne = TSNE(n_components=2,metric='precomputed',verbose=2,n_iter=2000,perplexity=5,early_exaggeration = 6,learning_rate=20)
X_embedded = tsne.fit_transform(cosine_matrix2)
df_subset = {} 
df_subset['tsne-2d-one'] = X_embedded[:,0]
df_subset['tsne-2d-two'] = X_embedded[:,1]
plt.figure(figsize=(16,10))
p1 = sns.scatterplot(X_embedded[:,0], X_embedded[:,1], legend='full', palette=palette)
for line in range(0,embed_mat.shape[0]):
     p1.text(df_subset['tsne-2d-one'][line]+0.01, df_subset['tsne-2d-two'][line], 
     headerText[line], horizontalalignment='left', 
     size='small', color='black', weight='semibold')
# Out:
# Loading the word embeddings from the disk
# Embedding shape: (54, 5)
# [[0.         0.42528234 0.4778818  ... 0.4270018  0.80679483 0.23623259]
#  [0.42528234 0.         0.04318056 ... 0.10804104 0.13855603 0.13716432]
#  [0.4778818  0.04318056 0.         ... 0.20825535 0.08543123 0.1418319 ]
#  ...
#  [0.4270018  0.10804104 0.20825535 ... 0.         0.3160606  0.22761077]
#  [0.80679483 0.13855603 0.08543123 ... 0.3160606  0.         0.258429  ]
#  [0.23623259 0.13716432 0.1418319  ... 0.22761077 0.258429   0.        ]]
# (54, 54)
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 54 samples in 0.000s...
# [t-SNE] Computed neighbors for 54 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 54 / 54
# [t-SNE] Mean sigma: 0.107652
# [t-SNE] Computed conditional probabilities in 0.002s
# [t-SNE] Iteration 50: error = 21.2268467, gradient norm = 0.7596843 (50 iterations in 0.014s)
# [t-SNE] Iteration 100: error = 21.2459145, gradient norm = 0.5784886 (50 iterations in 0.014s)
# [t-SNE] Iteration 150: error = 21.3274879, gradient norm = 0.6851268 (50 iterations in 0.014s)
# [t-SNE] Iteration 200: error = 21.1015244, gradient norm = 0.4357919 (50 iterations in 0.015s)
# [t-SNE] Iteration 250: error = 21.3101444, gradient norm = 0.6495212 (50 iterations in 0.015s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 21.310144
# [t-SNE] Iteration 300: error = 0.3822355, gradient norm = 0.0041000 (50 iterations in 0.015s)
# [t-SNE] Iteration 350: error = 0.3693112, gradient norm = 0.0010129 (50 iterations in 0.015s)
# [t-SNE] Iteration 400: error = 0.3652231, gradient norm = 0.0003897 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.3629462, gradient norm = 0.0002830 (50 iterations in 0.013s)
# [t-SNE] Iteration 500: error = 0.3612193, gradient norm = 0.0003291 (50 iterations in 0.014s)
# [t-SNE] Iteration 550: error = 0.3604143, gradient norm = 0.0001914 (50 iterations in 0.013s)
# [t-SNE] Iteration 600: error = 0.3596484, gradient norm = 0.0001711 (50 iterations in 0.015s)
# [t-SNE] Iteration 650: error = 0.3589997, gradient norm = 0.0001607 (50 iterations in 0.014s)
# [t-SNE] Iteration 700: error = 0.3587971, gradient norm = 0.0002033 (50 iterations in 0.015s)
# [t-SNE] Iteration 750: error = 0.3579370, gradient norm = 0.0001313 (50 iterations in 0.016s)
# [t-SNE] Iteration 800: error = 0.3580981, gradient norm = 0.0001612 (50 iterations in 0.016s)
# [t-SNE] Iteration 850: error = 0.3575513, gradient norm = 0.0001054 (50 iterations in 0.013s)
# [t-SNE] Iteration 900: error = 0.3570627, gradient norm = 0.0001614 (50 iterations in 0.015s)
# [t-SNE] Iteration 950: error = 0.3568512, gradient norm = 0.0001861 (50 iterations in 0.015s)
# [t-SNE] Iteration 1000: error = 0.3564480, gradient norm = 0.0001090 (50 iterations in 0.014s)
# [t-SNE] Iteration 1050: error = 0.3560907, gradient norm = 0.0001504 (50 iterations in 0.016s)
# [t-SNE] Iteration 1100: error = 0.3559336, gradient norm = 0.0001277 (50 iterations in 0.015s)
# [t-SNE] Iteration 1150: error = 0.3556335, gradient norm = 0.0001117 (50 iterations in 0.013s)
# [t-SNE] Iteration 1200: error = 0.3554720, gradient norm = 0.0001310 (50 iterations in 0.013s)
# [t-SNE] Iteration 1250: error = 0.3554348, gradient norm = 0.0001579 (50 iterations in 0.014s)
# [t-SNE] Iteration 1300: error = 0.3553062, gradient norm = 0.0001228 (50 iterations in 0.013s)
# [t-SNE] Iteration 1350: error = 0.3550744, gradient norm = 0.0000886 (50 iterations in 0.013s)
# [t-SNE] Iteration 1400: error = 0.3549182, gradient norm = 0.0000878 (50 iterations in 0.014s)
# [t-SNE] Iteration 1450: error = 0.3551195, gradient norm = 0.0001322 (50 iterations in 0.014s)
# [t-SNE] Iteration 1500: error = 0.3549914, gradient norm = 0.0000907 (50 iterations in 0.013s)
# [t-SNE] Iteration 1550: error = 0.3552165, gradient norm = 0.0000984 (50 iterations in 0.013s)
# [t-SNE] Iteration 1600: error = 0.3553271, gradient norm = 0.0000467 (50 iterations in 0.014s)
# [t-SNE] Iteration 1650: error = 0.3546908, gradient norm = 0.0001105 (50 iterations in 0.016s)
# [t-SNE] Iteration 1700: error = 0.3547785, gradient norm = 0.0000627 (50 iterations in 0.014s)
# [t-SNE] Iteration 1750: error = 0.3546263, gradient norm = 0.0001055 (50 iterations in 0.014s)
# [t-SNE] Iteration 1800: error = 0.3546616, gradient norm = 0.0000745 (50 iterations in 0.014s)
# [t-SNE] Iteration 1850: error = 0.3544343, gradient norm = 0.0000955 (50 iterations in 0.015s)
# [t-SNE] Iteration 1900: error = 0.3544487, gradient norm = 0.0000946 (50 iterations in 0.015s)
# [t-SNE] Iteration 1950: error = 0.3544693, gradient norm = 0.0000918 (50 iterations in 0.014s)
# [t-SNE] Iteration 2000: error = 0.3544272, gradient norm = 0.0000851 (50 iterations in 0.014s)
# [t-SNE] KL divergence after 2000 iterations: 0.354427

# %%
from sklearn.manifold import MDS
embedding = MDS(n_components=2,verbose=1,dissimilarity='precomputed',n_init=10)
X_transformed = embedding.fit_transform(cosine_matrix)
print(X_transformed.shape)


df_subset2 = {} 
df_subset2['mds-2d-one'] = X_transformed[:,0]
df_subset2['mds-2d-two'] = X_transformed[:,1]
plt.figure(figsize=(16,10))
p2 = sns.scatterplot(X_transformed[:,0], X_transformed[:,1], legend='full', palette=palette)
for line in range(0,embed_mat.shape[0]):
     p2.text(df_subset2['mds-2d-one'][line]+0.01, df_subset2['mds-2d-two'][line], 
     headerText[line], horizontalalignment='left', 
     size='small', color='black', weight='semibold')
# Out:
# breaking at iteration 163 with stress 57.61733866594239
# breaking at iteration 113 with stress 59.95958125747535
# breaking at iteration 99 with stress 60.31134492835632
# breaking at iteration 178 with stress 61.22792027187104
# breaking at iteration 123 with stress 61.64724477490467
# breaking at iteration 211 with stress 60.1991942248481
# breaking at iteration 170 with stress 56.296306691516826
# breaking at iteration 90 with stress 58.584820523243195
# breaking at iteration 178 with stress 62.03555890947118
# breaking at iteration 112 with stress 55.82946237346201
# (54, 2)
